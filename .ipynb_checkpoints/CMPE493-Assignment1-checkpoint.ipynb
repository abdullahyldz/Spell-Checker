# %%
import re
import pandas as pd

# %%
def editDistance(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    distanceMap = [[0] for i in range(len1+1)]
    distanceMap[0] = [i for i in range(len2+1)]
    for i in range(len1+1):
        distanceMap[i][0] = i
    
    for i in range(len1):
        for j in range(len2):
            adder = 0 if(word1[i]==word2[j]) else 1
            dist = min(distanceMap[i+1][j]+1,distanceMap[i][j+1]+1,distanceMap[i][j]+adder)
            distanceMap[i+1].append(dist)
    
    return distanceMap[len1][len2]

# %%
def D_L_editDistance(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    distanceMap = [[0] for i in range(len1+1)]
    distanceMap[0] = [i for i in range(len2+1)]
    for i in range(len1+1):
        distanceMap[i][0] = i
    
    for i in range(1,len1+1):
        for j in range(1,len2+1):
            adder = 0 if(word1[i-1]==word2[j-1]) else 1
            #print(i,j,adder)
            dist = min(distanceMap[i][j-1]+1,distanceMap[i-1][j]+1,distanceMap[i-1][j-1]+adder)
            if(i>1 and j>1 and word1[i-2:i] == word2[j-2:j][::-1]):
                dist = min(distanceMap[i-2][j-2]+1, dist)
            distanceMap[i].append(dist)
    #print(distanceMap)
    return distanceMap[len1][len2]

# %%
def D_L_Backtrack(word1, word2):
    len1 = len(word1)
    len2 = len(word2)
    distanceMap = [[0] for i in range(len1+1)]
    distanceMap[0] = [i for i in range(len2+1)]
    for i in range(len1+1):
        distanceMap[i][0] = i
    
    for i in range(1,len1+1):
        for j in range(1,len2+1):
            adder = 0 if(word1[i-1]==word2[j-1]) else 1
            #print(i,j,adder)
            dist = min(distanceMap[i][j-1]+1,distanceMap[i-1][j]+1,distanceMap[i-1][j-1]+adder)
            if(i>1 and j>1 and word1[i-2:i] == word2[j-2:j][::-1]):
                dist = min(distanceMap[i-2][j-2]+1, dist)
            distanceMap[i].append(dist)
    #print(distanceMap)
#     for i in range(len1+1, 0, -1):
#         for j in range(len2+1, 0, -1):
    i = len1
    j = len2
    print(i,j)
    operations = []
    while(i>=1 and j>=1):
        if(distanceMap[i][j] == distanceMap[i][j-1]+1):
            print('insertion of %s after %s' % (word2[j-1], word1[i-1]))
            operations.append(('insertion', word2[j-1], word1[i-1]))
            j=j-1
        elif(distanceMap[i][j] == distanceMap[i-1][j]+1):
            print('deletion of %s after %s' % (word1[i-1], word1[i-2]))
            operations.append(('deletion', word1[i-1], word1[i-2]))
            i=i-1
        elif(distanceMap[i][j] == distanceMap[i-1][j-1] + (0 if word1[i-1] == word2[j-1] else 1)):
            print('substitution of %s with %s' % (word2[j-1], word1[i-1]))
            operations.append(('substitution', word2[j-1], word1[i-1]))
            i=i-1
            j=j-1
        else:
            print('transposition of %s with %s' % (word2[j-1], word1[i-1]))
            operations.append(('transposition', word2[j-1], word1[i-1]))
            i=i-2
            j=j-2
    word1=word1[:-1]+'@'
    word2=word2[:-1]+'@'
    while(i>0):
        print('deletion of %s after %s' % (word1[i-1], word1[i-2]))
        operations.append(('deletion', word1[i-1], word1[i-2]))
        i=i-1
    while(j>0):
        print('insertion of %s after %s' % (word2[j-1], word1[i-1]))
        operations.append(('insertion', word2[j-1], word1[i-1]))
        j=j-1
    print(i,j)
    return operations

# %%
D_L_Backtrack( 'abdullah','abdulla')
# Out:
# 8 7
# deletion of h after a
# substitution of a with a
# substitution of l with l
# substitution of l with l
# substitution of u with u
# substitution of d with d
# substitution of b with b
# substitution of a with a
# 0 0
# [('deletion', 'a', 'l'),
#  ('substitution', 'l', 'l'),
#  ('substitution', 'l', 'l'),
#  ('substitution', 'u', 'u'),
#  ('substitution', 'd', 'd'),
#  ('substitution', 'b', 'b'),
#  ('substitution', 'a', 'a'),
#  ('substitution', 'a', 'h')]

# %%
word1 = 'do'
word2 = 'od'
i = j = 2
print(word1[0:2])
# Out:
# do

# %%
corpus = open('corpusMini.txt').read().lower()

# %%
test_words_correct = []
with open('test-words-correct.txt') as fp:
    line = fp.readline()
    while(line):
        test_words_correct.append(line[:-1])
        line = fp.readline()
test_words_misspelled = []
with open('test-words-misspelled.txt') as fp2:
    line = fp2.readline()
    while(line):
        test_words_misspelled.append(line[:-1])
        line = fp2.readline()

# %%
spell_errors = []
with open('spell-errors.txt') as fp:
    line = fp.readline()
    while(line):
        spell_errors.append(line[:-1])
        line = fp.readline()

# %%
spell_error_samples = {}
for spl_error in spell_errors:
    spl = spl_error.split(':')
    spell_error_samples[spl[0]] = []
    splErrors = spl[1].split(',')
    for err in splErrors:
        spell_error_samples[spl[0]].append(err.replace(' ', ''))

# %%
for se in spell_error_samples.items():
    spell_error_samples[se[0]] = []
    for err in se[1]:
        if('*' in err):
            sp = err.split('*')
            spell_error_samples[se[0]].append((sp[0], sp[1]))
        else:
            spell_error_samples[se[0]].append((err,1))

# %%
spell_error_samples
# Out:
# {'raining': [('rainning', 1), ('raning', 1)],
#  'writings': [('writtings', 1)],
#  'disparagingly': [('disparingly', 1)],
#  'yellow': [('yello', 1)],
#  'four': [('forer', 1),
#   ('fours', 1),
#   ('fuore', 1),
#   ('fore', '5'),
#   ('for', '4')],
#  'woods': [('woodes', 1)],
#  'hanging': [('haing', 1)],
#  'aggression': [('agression', 1)],
#  'looking': [('loking', 1),
#   ('begining', 1),
#   ('luing', 1),
#   ('look', '2'),
#   ('locking', 1),
#   ('lucking', 1),
#   ('louk', 1),
#   ('looing', 1),
#   ('lookin', 1),
#   ('liking', 1)],
#  'eligible': [('eligble', 1), ('elegable', 1), ('eligable', 1)],
#  'electricity': [('electrisity', 1), ('electricty', '2'), ('electrizity', 1)],
#  'scold': [('schold', 1), ('skold', 1)],
#  'adaptable': [('adabtable', 1)],
#  'caned': [('canned', 1), ('cained', 1)],
#  'immature': [('imature', 1)],
#  "shouldn't": [('shoudln', 1), ('shouldnt', 1)],
#  'swivel': [('swival', 1)],
#  'appropriation': [('apropriation', 1)],
#  'fur': [('furr', 1), ('fer', 1)],
#  'stabbed': [('stabed', 1)],
#  'Southwold': [('Suothwode', 1)],
#  'disturb': [('distrebe', 1), ('desturb', 1)],
#  'recollections': [('reclections', 1), ('recolections', 1)],
#  'prize': [('prise', 1), ('prizer', 1)],
#  'wednesday': [('wensday', 1), ('wedensday', 1)],
#  'succession': [('sucession', 1), ('sucesion', 1), ('succesion', 1)],
#  'straight': [('strate', 1), ('strait', 1), ('staidght', 1), ('stright', '2')],
#  'guardsmen': [('gards_men', 1)],
#  'incremented': [('increented', 1)],
#  'bacon': [('backen', 1), ('baken', 1)],
#  'pulse': [('pluse', 1)],
#  'elegant': [('elagent', 1), ('elligit', 1)],
#  'second': [('secand', 1),
#   ('sexeon', 1),
#   ('secund', 1),
#   ('seconnd', 1),
#   ('seond', 1),
#   ('sekon', 1)],
#  'jamjar': [('jam_jar', 1)],
#  'sailed': [('saled', 1), ('saild', 1)],
#  'blouse': [('boludes', 1)],
#  'thunder': [('thounder', 1)],
#  'cooking': [('coking', 1), ('chocking', 1), ('kooking', 1), ('cocking', 1)],
#  'fossil': [('fosscil', 1)],
#  'increasing': [('incased', 1),
#   ('ingreesh_this', 1),
#   ('incresing', 1),
#   ('incriosing', 1),
#   ('increacing', 1),
#   ('incressing', 1),
#   ('increcing', 1),
#   ('ingeker', 1),
#   ('incrsin', 1),
#   ('inceasing', 1),
#   ('inceing', 1),
#   ('increase', 1),
#   ('insest', 1),
#   ('ingcresing', 1),
#   ('incuiseing', 1),
#   ('enchres', 1),
#   ('intheris', 1),
#   ('incesing', 1),
#   ('encreing', 1),
#   ('increesing', 1),
#   ('crace', 1),
#   ('encrising', 1),
#   ('increaseng', 1),
#   ('encressing', 1),
#   ('in_cresing', 1),
#   ('incrising', 1),
#   ('incersinges', 1),
#   ('changing', 1),
#   ('incesting', 1),
#   ('encreasing', 1),
#   ('crissing', 1),
#   ('incriasing', 1),
#   ('incsin', 1),
#   ('incing', 1),
#   ('increaseing', 1),
#   ('ingesing', 1),
#   ('imceasing', 1),
#   ('incristing', 1),
#   ('engressing', 1),
#   ('ingresin', 1),
#   ('incrase', 1),
#   ('encash', 1)],
#  'hero': [('heroe', 1)],
#  'dahl': [('dael', 1)],
#  'reporter': [('repoter', 1),
#   ('rebarter', 1),
#   ('reportor', 1),
#   ('reproter', 1),
#   ('reoporter', 1),
#   ('repoted', 1),
#   ('reporet', 1),
#   ('peportery', 1)],
#  'interrupting': [('interupting', 1)],
#  'here': [('hiar', 1),
#   ('hare', 1),
#   ('hir', 1),
#   ('hair', 1),
#   ('haiw', 1),
#   ('liet', 1),
#   ('hreb', 1),
#   ('hah', 1),
#   ('her', 1),
#   ('hes', 1),
#   ('hiyr', 1),
#   ('there', 1),
#   ('three', 1),
#   ('hay', 1),
#   ('hea', 1),
#   ('herre', 1),
#   ('har', 1),
#   ('werr', 1),
#   ('head', 1),
#   ('heere', 1),
#   ('hera', 1),
#   ('heir', 1),
#   ('herd', 1),
#   ('heat', 1),
#   ('hear', '11'),
#   ('handr', 1),
#   ('he', 1),
#   ('heer', 1),
#   ('hree', 1),
#   ('hire', 1),
#   ('thehe', 1),
#   ('hon', 1),
#   ('eate', 1),
#   ('poit', 1)],
#  'atoms': [('atom', 1)],
#  'tape-recorded': [('tape_recorded', 1)],
#  'shriek': [('shreik', 1)],
#  'substance': [('substace', 1)],
#  'elaborate': [('elaberate', 1)],
#  'climbed': [('climb', 1), ('climed', 1), ('cimed', 1)],
#  'reports': [('reoprts', 1)],
#  'controversy': [('contervercing', 1),
#   ('contervercuy', 1),
#   ('consonerse', 1),
#   ('counteversy', 1),
#   ('contravercy', 1),
#   ('contronversey', 1),
#   ('contiversey', 1),
#   ('countirversay', 1),
#   ('countrovesy', 1),
#   ('counterversing', 1),
#   ('comsversiary', 1),
#   ('controversave', 1),
#   ('contevesy', 1),
#   ('controveries', 1),
#   ('controversey', 1),
#   ('controvercy', '2'),
#   ('contraversally', 1),
#   ('conteversy', 1),
#   ('comtevercy', 1),
#   ('controversaries', 1),
#   ('countufersey', 1),
#   ('controvarsey', 1),
#   ('conqouversing', 1),
#   ('contriversy', 1),
#   ('contraversey', 1),
#   ('controvesey', 1),
#   ('contraverse', 1),
#   ('countroversy', 1),
#   ('contraversy', '2'),
#   ('constroversy', 1),
#   ('contruevency', 1),
#   ('connesary', 1),
#   ('contavercy', 1),
#   ('conversity', 1),
#   ('contretearsing', 1),
#   ('controvery', 1),
#   ('contrevy', 1),
#   ('controvsary', 1),
#   ('contiuvisy', 1),
#   ('controvese', 1),
#   ('contronersery', 1),
#   ('controvorsey', 1),
#   ('contravorsy', 1),
#   ('countrevercy', 1),
#   ('controvvesity', 1),
#   ('conterversy', 1),
#   ('conterverisy', 1),
#   ('contriversey', 1),
#   ('conterversty', 1),
#   ('contreversey', 1),
#   ('combtrovesy', 1),
#   ('conversey', 1),
#   ('contterversy', 1),
#   ('conturvesy', 1),
#   ('contrvercy', 1),
#   ('controvesy', 1),
#   ('coutueversy', 1),
#   ('controsory', 1),
#   ('contrefercing', 1),
#   ('counterners', 1),
#   ('controvercey', 1),
#   ('contowversie', 1),
#   ('controversay', 1),
#   ('conversation', 1),
#   ('controversary', 1),
#   ('contraversery', 1),
#   ('contreversy', 1),
#   ('controversie', 1),
#   ('contriverse', 1),
#   ('controversing', 1),
#   ('conterversay', 1),
#   ('contrusy', 1)],
#  'etiology': [('eitiology', 1)],
#  'snowing': [('showing', 1)],
#  'military': [('millitary', 1), ('milatary', 1), ('militery', 1)],
#  'cancellation': [('canselation', 1),
#   ('cassilation', 1),
#   ('canncelation', 1),
#   ('cancalation', 1),
#   ('consulation', 1),
#   ('cancelatin', 1),
#   ('canelation', 1),
#   ('cansallation', 1),
#   ('cansellation', 1),
#   ('cansilation', 1),
#   ('cancallation', 1),
#   ('canacellation', 1),
#   ('cannsulation', 1),
#   ('cansaltion', 1),
#   ('cancolateon', 1),
#   ('cansulation', 1),
#   ('consalation', 1),
#   ('canselution', 1),
#   ('cancilliation', 1),
#   ('canslation', 1),
#   ('cancillation', 1),
#   ('cancolation', 1),
#   ('cansalation', 1),
#   ('cancialation', 1),
#   ('cancatation', 1),
#   ('cancilation', 1),
#   ('canclation', 1),
#   ('cansolitation', 1),
#   ('cansolation', 1),
#   ('cancealation', 1),
#   ('cancilion', 1),
#   ('cancelation', 1),
#   ('chancelation', 1),
#   ('cansclitation', 1)],
#  'criticism': [('criticisim', 1),
#   ('critizeation', 1),
#   ('criticizem', 1),
#   ('coritisumn', 1),
#   ('critisicsm', 1),
#   ('criticisam', 1),
#   ('critisizem', 1),
#   ('critisium', 1),
#   ('critizition', 1),
#   ('critisisem', 1),
#   ('crisisem', 1),
#   ('critiscism', 1),
#   ('critisisum', 1),
#   ('critigism', 1),
#   ('critisum', 1),
#   ('critizim', 1),
#   ('certsemus', 1),
#   ('griticism', 1),
#   ('critizm', 1),
#   ('critizesum', 1),
#   ('cretism', 1),
#   ('crisizum', 1),
#   ('critisima', 1),
#   ('critizam', 1),
#   ('critisizum', 1),
#   ('critisiem', 1),
#   ('criticisiom', 1),
#   ('critisim', 1),
#   ('critizizem', 1),
#   ('critisizm', 1),
#   ('critisism', '2'),
#   ('critisiciam', 1),
#   ('crictism', 1),
#   ('critizium', 1),
#   ('critisicm', 1),
#   ('crittissisam', 1),
#   ('criticiz', 1),
#   ('criticisium', 1),
#   ('critisyum', 1),
#   ('critisicem', 1),
#   ('critissam', 1),
#   ('criticiam', 1),
#   ('citisum', 1),
#   ('critizom', 1),
#   ('critiszm', 1),
#   ('criticise', 1),
#   ('critisisim', 1),
#   ('criticisum', 1),
#   ('criticizement', 1),
#   ('cridictcisim', 1),
#   ('criticisms', 1),
#   ('critisizime', 1),
#   ('criticisem', 1),
#   ('critisizim', 1),
#   ('critisision', 1),
#   ('critizism', 1),
#   ('crisiam', 1),
#   ('critisisam', 1),
#   ('criticsm', 1),
#   ('critisiam', 1),
#   ('criticizasm', 1),
#   ('critizum', 1),
#   ('criticizin', 1),
#   ('critizisum', 1),
#   ('critizen', 1),
#   ('critizem', 1),
#   ('critzen', 1),
#   ('cretacesum', 1),
#   ('courtesisum', 1),
#   ('critisym', 1),
#   ('cretisism', 1),
#   ('critizisim', 1),
#   ('criticitisem', 1),
#   ('crypticism', 1),
#   ('critizizam', 1),
#   ('critisesimon', 1),
#   ('critisem', 1),
#   ('critcism', 1),
#   ('criticem', 1),
#   ('criciticisms', 1),
#   ('cirtissimum', 1),
#   ('critici', 1),
#   ('criticm', 1),
#   ('critism', 1),
#   ('critision', 1),
#   ('crytisym', 1),
#   ('criticizm', 1),
#   ('courtisum', 1),
#   ('critisizen', 1),
#   ('critizitim', 1),
#   ('criticum', 1)],
#  'golden': [('goldin', 1), ('gloden', 1)],
#  'sines': [('sinse', 1)],
#  'divide': [('devide', '2'), ('divid', 1)],
#  'subtracts': [('substracts', 1)],
#  'there_had': [('therad', 1)],
#  'criticise': [('critisize', 1)],
#  'sweetest': [('sweetes', 1)],
#  'explained': [('explan', 1),
#   ('epled', 1),
#   ('exclimed', 1),
#   ('exeplande', 1),
#   ('explainded', 1),
#   ('ecspained', 1),
#   ('explard', 1),
#   ('exslanded', 1),
#   ('explanned', 1),
#   ('expanel', 1),
#   ('exesnd', 1),
#   ('expaned', 1),
#   ('exlpand', 1),
#   ('explain', 1),
#   ('explaind', 1),
#   ('eixplaned', 1),
#   ('exsplaned', 1),
#   ('eplained', 1),
#   ('exsplain', 1),
#   ('explaid', 1),
#   ('explaned', 1),
#   ('epland', 1),
#   ('expand', 1),
#   ('extamed', 1),
#   ('explant', 1),
#   ('ekplaned', 1),
#   ('expaine', 1),
#   ('exploxen', 1),
#   ('explairded', 1),
#   ('explane', 1),
#   ('expland', 1),
#   ('expent', 1),
#   ('exclaimed', 1),
#   ('exprand', 1),
#   ('exple', 1),
#   ('exclamed', 1)],
#  'brought': [('broght', 1),
#   ('broug', 1),
#   ('brough', '2'),
#   ('brot', 1),
#   ('bught', 1),
#   ('brort', 1),
#   ('brougth', 1),
#   ('bought', 1)],
#  'remnant': [('reminent', 1)],
#  'sizeable': [('sizable', 1)],
#  'opponents': [('oppenerts', 1)],
#  'spoke': [('spoak', 1), ('spock', 1), ('spok', 1), ('spook', 1)],
#  'browse': [('bbrose', 1)],
#  'music': [('muic', 1), ('muice', 1)],
#  'telegraph': [('telagraph', 1)],
#  'strike': [('stricke', 1), ('sricke', 1), ('strick', 1)],
#  'until': [('intal', 1), ('untill', '9'), ('uatill', 1), ('untl', 1)],
#  'holy': [('wholy', 1), ('holly', 1), ('holey', 1)],
#  'relax': [('relacks', 1)],
#  'successful': [('sucksesful', 1),
#   ('sucsselful', 1),
#   ('seckesful', 1),
#   ('sacsesful', 1),
#   ('sussecful', 1),
#   ('sucsesfult', 1),
#   ('sususful', 1),
#   ('seccesful', 1),
#   ('suxsesful', 1),
#   ('sucsful', 1),
#   ('sussfull', 1),
#   ('sucsesfull', 1),
#   ('sucssuful', 1),
#   ('sucsessful', 1),
#   ('siccesefull', 1),
#   ('sursenful', 1),
#   ('suxsusful', 1),
#   ('suksesfull', 1),
#   ('succful', 1),
#   ('successfull', '2'),
#   ('sucessful', 1),
#   ('succesfull', 1),
#   ('secsecfuly', 1),
#   ('sucessfull', '2'),
#   ('successeful', 1),
#   ('suxcessful', 1),
#   ('sesesful', 1),
#   ('scucfull', 1),
#   ('succesfel', 1),
#   ('sexcful', 1),
#   ('suckessful', 1),
#   ('succsesfull', 1),
#   ('secessful', 1),
#   ('sucfull', 1),
#   ('successfuly', 1),
#   ('seceful', 1),
#   ('suckcesfull', 1),
#   ('surseful', 1),
#   ('saseful', 1),
#   ('sucksfull', 1),
#   ('susesful', 1),
#   ('surou', 1),
#   ('sucefull', 1),
#   ('succeful', 1),
#   ('sucsfully', 1),
#   ('sexself', 1),
#   ('succesfully', 1),
#   ('uscsful', 1),
#   ('sucesful', '2'),
#   ('sucseful', 1),
#   ('succfull', 1),
#   ('succusfull', 1),
#   ('secsecful', 1),
#   ('sucksesfull', 1),
#   ('suchsefull', 1),
#   ('sacksesful', 1),
#   ('scuksefuly', 1),
#   ('succesful', '2'),
#   ('sucsefully', 1),
#   ('secseful', 1),
#   ('succeshful', 1),
#   ('sucsessfull', 1),
#   ('suchesbull', 1),
#   ('sucsesfle', 1),
#   ('suxsefal', 1),
#   ('sucsesful', 1),
#   ('suceseful', 1),
#   ('sukseful', 1),
#   ('succsessful', 1),
#   ('succsefull', 1),
#   ('suskfull', 1),
#   ('suceful', 1),
#   ('sucesfull', 1),
#   ('succsesful', 1),
#   ('sucesfful', 1),
#   ('sussefull', 1),
#   ('secsesful', 1)],
#  'hurt': [('heart', 1), ('hert', '3'), ('hearte', 1)],
#  'glass': [('glas', 1), ('glars', 1)],
#  'reversible': [('reversable', 1)],
#  'tying': [('tieing', 1)],
#  'hole': [('hol', 1), ('hold', 1), ('holler', 1)],
#  'hold': [('hod', 1), ('holed', 1)],
#  'circumstances': [('circumstaces', 1)],
#  'locked': [('lock', 1), ('lockEd', 1), ('lockd', 1)],
#  'pursue': [('persue', '3'), ('presue', 1)],
#  'accomplishment': [('acomplishment', 1)],
#  'apologetics': [('apolegetics', 1)],
#  'locker': [('loker', 1)],
#  'example': [('exemple', 1), ('exmaple', 1), ('exsample', 1), ('exmple', 1)],
#  'household': [('houshe', 1)],
#  'artillery': [('artillary', 1)],
#  'organized': [('oranised', 1), ('orginized', 1)],
#  'caution': [('causion', 1), ('cortion', 1)],
#  'want': [('wont', 1),
#   ('wants', 1),
#   ('what', 1),
#   ('mant', 1),
#   ('whant', '7'),
#   ('wand', 1),
#   ('watn', 1),
#   ("whan't", '2'),
#   ('woth', 1),
#   ('wnat', 1),
#   ('whon', 1),
#   ('whont', '5'),
#   ("won't", '4'),
#   ('wernt', 1),
#   ('went', 1),
#   ('wat', 1)],
#  'preferably': [('preferrably', 1)],
#  'hog': [('hag', 1)],
#  'hoe': [('how', 1), ('ho', 1)],
#  'complaining': [('complanig', 1)],
#  'travel': [('travle', 1), ('travill', 1), ('travell', 1)],
#  'damage': [('damaged', 1),
#   ('damadge', 1),
#   ('Dameage', 1),
#   ('damge', 1),
#   ('Damage', 1),
#   ('dammage', 1),
#   ('damuge', 1),
#   ('damagage', 1),
#   ('damaze', 1),
#   ('danage', 1),
#   ('damnage', 1),
#   ('damgous', 1)],
#  'machine': [('mecichly', 1),
#   ('merchen', 1),
#   ('meshien', 1),
#   ('michin', 1),
#   ('minhen', 1),
#   ('machane', 1),
#   ('merchain', 1),
#   ('mishn', 1),
#   ('maechen', 1),
#   ('mosien', 1),
#   ('moter', 1),
#   ('masir', 1),
#   ('matchine', 1),
#   ('macine', 1),
#   ('mashen', 1),
#   ('machiene', 1),
#   ('merchine', 1),
#   ('mishing', 1),
#   ('meirshin', 1),
#   ('mechine', 1),
#   ('micshine', 1),
#   ('mashin', 1),
#   ('mashine', 1),
#   ('manchine', 1),
#   ('mching', 1),
#   ('mesen', 1),
#   ('macien', 1),
#   ('muchien', 1),
#   ('mrosin', 1),
#   ('machian', 1),
#   ('masgen', 1),
#   ('mshin', 1),
#   ('machein', 1),
#   ('macheine', 1)],
#  'how': [('hou', 1), ('haw', 1)],
#  'hot': [('thot', 1),
#   ('rat', 1),
#   ('hoot', 1),
#   ('hala', 1),
#   ('hote', 1),
#   ('aht', 1),
#   ('tert', 1),
#   ('hat', 1)],
#  'hop': [('hope', 1)],
#  'cheetah': [('cheter', '3')],
#  'preferable': [('preferrable', 1)],
#  'fanaticism': [('fanatism', 1)],
#  'vaccination': [('vacinnation', 1)],
#  'beauty': [('beuty', 1), ('bueaty', 1)],
#  'outlawed': [('oulawed', 1)],
#  'wrong': [('wrang', 1),
#   ('wronge', 1),
#   ('ron', 1),
#   ('rong', '3'),
#   ('long', 1),
#   ('rog', 1),
#   ('wong', 1),
#   ('ronge', 1),
#   ('ro', 1),
#   ('worng', 1)],
#  'monolithic': [('monolite', 1)],
#  'short-tempered': [('short_tempered', 1)],
#  'effective': [('affective', 1)],
#  'caisson': [('casion', 1)],
#  'headquarters': [('headquoters', 1)],
#  'season': [('seson', 1)],
#  'signatories': [('signitories', 1)],
#  'baggage': [('bagage', 1)],
#  'orally': [('erally', 1)],
#  'snowballs': [('snow_ball', 1)],
#  'keeps': [('keep', 1)],
#  'wind': [('win', 1), ('wid', 1)],
#  'restriction': [('restrici', 1)],
#  'dreamed': [('dremd', 1)],
#  'misdemeanor': [('misdemenor', 1), ('misdameanor', 1)],
#  'vary': [('varie', 1)],
#  'sunshine': [('sunshin', 1)],
#  'Nazareth': [('Nazereth', 1)],
#  'fir': [('fur', 1)],
#  'His': [("He's", 1), ('He', 1)],
#  'fit': [('fite', 1), ('fanit', 1), ('fid', 1)],
#  'unforeseen': [('unforseen', 1)],
#  'heretofore': [('heretofor', 1)],
#  'secede': [('seceed', 1)],
#  'survivors': [('survivers', 1)],
#  'coach-load': [('coach_load', 1)],
#  'distinguishing': [('distingishing', 1)],
#  'insubstantial': [('insubstancial', 1)],
#  'hidden': [('hidon', 1)],
#  'Him': [('Im', '2')],
#  'grievous': [('grievious', 1)],
#  'interrupt': [('interupt', '2')],
#  'blink': [('blnk', 1)],
#  'eisenhower': [('eisenhhower', 1)],
#  'scholar': [('scholer', 1)],
#  'rumour': [('rumer', 1), ('rummer', 1)],
#  'represents': [('repreents', 1)],
#  'queues': [('ques', 1)],
#  'shoelace': [('shoe_lace', 1)],
#  'arrow': [('arow', 1)],
#  'volcano': [('volcanoe', 1)],
#  'dumpy': [('dunpty', 1)],
#  'obdurate': [('obdirate', 1)],
#  'preceded': [('preceeded', 1)],
#  'financial': [('vaysuntte', 1),
#   ('fiynalle', 1),
#   ('finachle', 1),
#   ('finashall', 1),
#   ('finaancle', 1),
#   ('finatul', 1),
#   ('finantual', 1),
#   ('fintrol', 1),
#   ('fina', 1),
#   ('finnance', 1),
#   ('financhial', 1),
#   ('finanturel', 1),
#   ('finasle', 1),
#   ('finanshel', 1),
#   ('fineshel', 1),
#   ('financal', 1),
#   ('finnanle', 1),
#   ('finanial', 1),
#   ('financhel', 1),
#   ('firanshal', 1),
#   ('finachial', 1),
#   ('finashal', 1),
#   ('finenashsure', 1),
#   ('finatial', 1),
#   ('finane', 1),
#   ('fianation', 1),
#   ('finantial', 1),
#   ('finacwell', 1),
#   ('firnashal', 1),
#   ('fenecherue', 1),
#   ('finanshiol', 1),
#   ('financual', 1),
#   ('finachel', 1),
#   ('finasial', 1),
#   ('finacal', 1),
#   ('finatoil', 1),
#   ('finantal', 1),
#   ('finacial', 1),
#   ('finesha', 1),
#   ('fiancial', 1),
#   ('finashel', 1),
#   ('finatical', 1),
#   ('firnanshel', 1),
#   ('finanction', 1),
#   ('fineancal', 1),
#   ('finalshal', 1),
#   ('financhall', 1)],
#  'snakes': [('snaks', 1), ('snake', 1)],
#  'archetypes': [('archtypes', 1)],
#  'garment': [('garmet', 1)],
#  'Teddy_boy': [('Teddoy', '3'), ('Tedeboy', 1)],
#  'spider': [('spiter', 1)],
#  'turnip': [('turnup', 1)],
#  'precedes': [('preceeds', 1)],
#  'fortnight': [('fort_night', 1)],
#  'laboratory': [('labory', 1),
#   ('labotorey', 1),
#   ('laboraty', 1),
#   ('labritory', 1),
#   ('labroratory', 1),
#   ('lavatory', 1),
#   ('labortory', 1),
#   ('labertory', 1),
#   ('labrotory', 1),
#   ('laboatory', 1),
#   ('libertory', 1),
#   ('labatory', 1),
#   ('laboretory', 1),
#   ('labratory', '2'),
#   ('laberotary', 1),
#   ('labitory', 1),
#   ('labaratory', 1),
#   ('labetory', 1),
#   ('lavoratory', 1),
#   ('elatory', 1),
#   ('lab', 1),
#   ('laveratory', 1),
#   ('labartory', 1),
#   ('labortary', 1),
#   ('laboritory', 1),
#   ('labority', 1),
#   ('laborotory', 1),
#   ('labarotory', 1),
#   ('lavortory', 1),
#   ('laborbtory', 1),
#   ('laberatory', 1),
#   ('lavratory', 1)],
#  'ring': [('rings', 1)],
#  'whip': [('wip', 1)],
#  'excepting': [('exepting', 1)],
#  'encourage': [('incourage', 1),
#   ('encorage', 1),
#   ('encourge', 1),
#   ('encourg', 1)],
#  'engineer': [('engeneer', 1), ('engieneer', 1), ('enginer', 1)],
#  'foundation': [('foundition', 1), ('fondation', 1)],
#  'inhabitants': [('habitants', 1)],
#  'assured': [('asured', 1)],
#  'threatened': [('thretened', 1)],
#  'surveys': [('survays', 1), ('servays', 1)],
#  'grapes': [('graps', 1)],
#  'sheet': [('sheat', '2'), ('shet', 1)],
#  'estimate': [('estamate', 1)],
#  'knit': [('knitt', 1), ('niet', 1), ('nit', 1)],
#  'universally': [('universaly', 1)],
#  'enormous': [('enormas', 1),
#   ('emerous', 1),
#   ('enourmous', 1),
#   ('enormus', 1)],
#  'ate': [('et', 1), ('aet', 1), ('eat', '3'), ('ete', 1)],
#  'scruff': [('scruf', 1)],
#  'reprimanded': [('repremanded', 1)],
#  'dinner-hour': [('dinner_hour', 1)],
#  "today's": [('todays', 1)],
#  'sallies': [('sally', 1)],
#  'wash': [('wach', 1), ('wosh', 1)],
#  'instruct': [('instruck', 1)],
#  'customization': [('custamisation', 1)],
#  'bitten': [('biten', 1)],
#  'rhododendron': [('rhododrendon', 1)],
#  'basketball': [('baskball', 1),
#   ('Basketball', 1),
#   ('basketbale', 1),
#   ('Basket-Ball', 1),
#   ('baskt-ball', 1),
#   ('baskeball', 1),
#   ('basket-ball', 1),
#   ('bascketball', 1),
#   ('basket-Ball', 1),
#   ('baskitball', 1),
#   ('bascket-ball', 1),
#   ('Basket_ball', 1),
#   ('bastestball', 1)],
#  'service': [('cirvice', 1), ('survice', 1), ('servise', 1), ('servace', 1)],
#  'similarly': [('similarily', '2')],
#  'engagement': [('enagement', 1)],
#  'needed': [('need', 1), ('nedded', 1), ('mided', 1), ('neaded', 1)],
#  'perturbations': [('pertubations', 1)],
#  'master': [('mater', 1)],
#  'architect': [('archetect', 1)],
#  'listen': [('lisen', 1),
#   ('lesson', 1),
#   ('lisn', 1),
#   ('leasten', 1),
#   ('listern', '2')],
#  'geneva': [('geniva', 1)],
#  'snooty': [('snoty', 1)],
#  'predictable': [('predicable', 1)],
#  'crawl': [('crol', 1), ('crall', 1)],
#  'positively': [('positivly', 1)],
#  'sidereal': [('sedereal', 1), ('sideral', 1)],
#  'showed': [('showd', 1), ('shod', 1)],
#  'approximations': [('appoximations', 1)],
#  'tree': [('treee', 1), ('tre', 1), ('three', 1), ('tee', 1)],
#  'omnivorous': [('omniverous', 1)],
#  'project': [('progetr', 1),
#   ('proget', 1),
#   ('prget', 1),
#   ('pojert', 1),
#   ('projer', 1),
#   ('prung', 1),
#   ('commet', 1),
#   ('pgett', 1),
#   ('projet', 1),
#   ('projoc', 1),
#   ('progect', 1),
#   ('porait', 1),
#   ('poujent', 1),
#   ('projent', 1),
#   ('projexty', 1),
#   ('poragced', 1),
#   ('porcet', 1)],
#  'pneumonia': [('nuemonia', 1),
#   ('memonia', 1),
#   ('pnenonia', 1),
#   ('pnuemonia', 1),
#   ('phneumonia', 1),
#   ('ammonia', 1),
#   ('pnmonia', 1),
#   ('phemonia', 1),
#   ('pneumaine', 1),
#   ('phneomia', 1),
#   ('phenomia', 1),
#   ('pnemounia', 1),
#   ('nomina', 1),
#   ('phenominia', 1),
#   ('phneomina', 1),
#   ('pnenumoia', 1),
#   ('phewmonia', 1),
#   ('pneimonia', 1),
#   ('newmonia', 1),
#   ('amnonnia', 1),
#   ('phemonuia', 1),
#   ('pneunomia', 1),
#   ('amomea', 1),
#   ('phenioma', 1),
#   ('nephonia', 1),
#   ('pheunomia', 1),
#   ('phenomenia', 1),
#   ('phunmonia', 1),
#   ('phnomeia', 1),
#   ('peneumia', 1),
#   ('phomonia', 1),
#   ('phumonia', 1),
#   ('pnumonia', 1),
#   ('pheuphmonia', 1),
#   ('pnemoninia', 1),
#   ('pneunonia', 1),
#   ('phonimonu', 1),
#   ('phuemonia', 1),
#   ('ponuime', 1),
#   ('anumonian', 1),
#   ('anomina', 1),
#   ('phnomia', 1),
#   ('pneaumonia', 1),
#   ('phenoumonia', 1),
#   ('Phnumonia', 1),
#   ('pnomonia', 1),
#   ('phenoumina', 1),
#   ('penmonia', 1),
#   ('phenoumia', 1),
#   ('newmony', 1),
#   ('phenumia', 1),
#   ('pnueounia', 1),
#   ('phenimonia', 1),
#   ('numonia', 1),
#   ('penominia', 1),
#   ('phnumonia', 1),
#   ('pounia', 1),
#   ('puemonia', 1),
#   ('pnemonia', 1),
#   ('pnenomionia', 1),
#   ('phenomu', 1),
#   ('pneumia', 1),
#   ('pneumnia', 1),
#   ('pheomena', 1),
#   ('pnenonea', 1),
#   ('phemomina', 1),
#   ('phenomnia', 1),
#   ('anonianu', 1),
#   ('phmoinia', 1),
#   ('pneurminu', 1),
#   ('phnemona', 1),
#   ('pheunomina', 1),
#   ('Pheumonia', 1),
#   ('phemonuime', 1),
#   ('Pneumonia', 1),
#   ('phnenimonia', 1),
#   ('pheumonia', 1),
#   ('phnuemonia', 1),
#   ('namoia', 1),
#   ('nephenoma', 1),
#   ('namouny', 1),
#   ('pheneumonia', 1),
#   ('pnumonenia', 1),
#   ('numonuia', 1),
#   ('pneumunia', 1),
#   ('nemonia', 1),
#   ('pnumonea', 1),
#   ('phunemonia', 1),
#   ('peunmonia', 1),
#   ('pneumphia', 1),
#   ('neumonia', 1),
#   ('pnenomia', 1),
#   ('knemonu', 1),
#   ('phnemonia', 1),
#   ('phnemounia', 1),
#   ('pnumeia', 1),
#   ('pneomonia', 1),
#   ('peunomia', 1),
#   ('phomoniow', 1),
#   ('Phonia', 1),
#   ('demondia', 1),
#   ('phmeuaina', 1),
#   ('phenemonia', 1),
#   ('numoia', 1),
#   ('remote', 1),
#   ('penumonia', 1),
#   ('munonia', 1),
#   ('phenumonia', 1),
#   ('pneuammia', 1),
#   ('amonia', 1)],
#  'idle': [('idel', 1), ('ide', 1)],
#  'readjusted': [('reajusted', 1)],
#  'seminary': [('seminery', 1)],
#  'feeling': [('feling', 1), ('felling', 1), ('fealing', 1)],
#  'acquisition': [('aquisistion', 1), ('aquisition', 1)],
#  'a_lot': [('lot', 1), ('alote', 1), ('alot', '2')],
#  "to-day's": [('two_days', 1),
#   ('todays', 1),
#   ("todays'", 1),
#   ('to-days', 1),
#   ("today's", 1),
#   ('todaies', 1),
#   ('to_days', 1)],
#  'runner': [('runer', 1)],
#  'dozen': [('doxen', 1), ('dosen', 1)],
#  'wholesome': [('wholsome', 1), ('holesome', 1)],
#  'courier': [('coururier', 1)],
#  'responsible': [('resmoserbl', 1),
#   ('responsable', 1),
#   ('responcible', 1),
#   ('reponsible', 1),
#   ('reposable', 1)],
#  'metallic': [('metalic', 1)],
#  'asymmetric': [('assymmetric', 1), ('asymetric', 1), ('assymetric', 1)],
#  'Bang': [('Bankg', '4')],
#  'causing': [('corsing', 1), ('coursing', 1)],
#  'absorbed': [('asorbed', 1), ('abo', 1)],
#  'amusing': [('amsing', 1)],
#  'doors': [('doers', 1), ('dors', 1)],
#  'responsibly': [('responsably', 1)],
#  'Jones': [('Johnes', 1)],
#  'committing': [('commiting', '2'), ('comiting', 1), ('comitting', 1)],
#  'shall': [('shale', 1), ('sall', 1), ('she', 1), ('shal', 1)],
#  'object': [('objet', 1)],
#  'a_little': [('alitl', 1), ('alittle', 1)],
#  'mouth': [('moth', 1)],
#  'letter': [('letre', 1), ('teller', 1), ('leter', 1)],
#  'conceded': [('conseived', 1)],
#  'professor': [('professer', 1),
#   ('profesor', 1),
#   ('proffessor', 1),
#   ('proffesor', '2')],
#  'camp': [('kamp', 1), ('canp', 1)],
#  'consummate': [('consumate', 1)],
#  'nineteenth': [('ninteenth', 1)],
#  'scream': [('scem', 1), ('screem', 1), ('screm', 1)],
#  'incomplete': [('incompleet', 1), ('incomplot', 1)],
#  'marvel': [('marval', 1)],
#  'polypropylene': [('polypropalene', 1)],
#  'bomb': [('baumb', 1),
#   ('bombe', 1),
#   ('bome', 1),
#   ('bomm', 1),
#   ('bown', 1),
#   ('bonod', 1),
#   ('book', 1),
#   ('bom', 1),
#   ('bambe', 1),
#   ('boom', 1)],
#  'insects': [('insexs', 1)],
#  'gauge': [('gadg', 1),
#   ('gape', 1),
#   ('garge', 1),
#   ('gare', 1),
#   ('gange', 1),
#   ('gang', 1),
#   ('tade', 1),
#   ('garer', 1),
#   ('gage', 1),
#   ('gach', 1),
#   ('gagde', 1),
#   ('cauge', 1),
#   ('gams', 1),
#   ('gadje', 1),
#   ('bergage', 1),
#   ('gradnang', 1),
#   ('gar', 1),
#   ('grage', 1),
#   ('gagech', 1),
#   ('garind', 1),
#   ('gag', 1),
#   ('gaog', 1),
#   ('cage', 1),
#   ('gargch', 1),
#   ('gadeg', 1),
#   ('rage', 1),
#   ('gaige', 1),
#   ('gade', 1),
#   ('gager', 1),
#   ('guage', 1),
#   ('gadge', 1),
#   ('ghase', 1),
#   ('guadge', 1),
#   ('gaoge', 1),
#   ('gaged', 1),
#   ('geich', 1)],
#  'lessons': [("lesson's", 1),
#   ('lessens', 1),
#   ('lesons', 1),
#   ('leasons', 1),
#   ('lessions', 1),
#   ('listerse', 1),
#   ('lesson', 1)],
#  'busy': [('bise', 1), ('buisy', 1), ('bussy', 1), ('bisy', 1)],
#  'shuffling': [('shufarling', 1)],
#  'than': [('then', 1), ('thna', 1), ('tahn', 1), ('that', 1)],
#  'bush': [('buch', '2')],
#  'touched': [('tesded', 1),
#   ('toure', 1),
#   ('cher', 1),
#   ('toched', 1),
#   ('theed', 1),
#   ('tost', 1),
#   ('tuched', 1),
#   ('tusted', 1),
#   ('toughed', 1),
#   ('tosh', 1),
#   ('touch', 1),
#   ('toached', 1),
#   ('tache', 1),
#   ('tucked', 1),
#   ('tust', 1),
#   ('tutet', 1),
#   ('toght', 1),
#   ('tuses', 1),
#   ('tush', 1),
#   ('tougched', 1),
#   ('tacah', 1),
#   ('tuchd', 1),
#   ('toch', 1),
#   ('toulched', 1),
#   ('turst', 1),
#   ('toutched', 1),
#   ('chuched', 1),
#   ('trosh', 1),
#   ('tiups', 1),
#   ('stuched', 1),
#   ('tuch', 1),
#   ('thach', 1),
#   ('touh', 1),
#   ('thucht', 1),
#   ('tashed', 1)],
#  'rich': [('rick', 1)],
#  'rice': [('rise', 1)],
#  'lady': [('lade', 1), ('ladey', 1), ('ladiy', 1), ('ladys', 1)],
#  'plate': [('blate', 1), ('plat', 1)],
#  'stammered': [('stamerd', 1)],
#  'terrors': [('terrours', 1)],
#  'foremost': [('formost', 1)],
#  'pocket': [('poket', 1)],
#  'foundries': [('foundaries', 1)],
#  'cushion': [('cusion', 1)],
#  'altogether': [('alltogether', 1), ('atlogeher', 1), ('all_together', 1)],
#  'jaguar': [('jagaur', 1)],
#  'nicely': [('nicerly', 1), ('nicly', 1), ('micely', 1)],
#  'boarder': [('border', 1)],
#  'patch': [('pacth', 1)],
#  'blew': [('blow', '3'), ('blue', 1)],
#  'disaster': [('diaster', 1)],
#  'fair': [('fare', 1)],
#  'peripheral': [('periferal', 1)],
#  'radius': [('radiuss', 1), ('radious', 1)],
#  'fail': [('fale', 1)],
#  'nocturnal': [('nocternal', 1)],
#  'hammer': [('hamer', 1)],
#  'best': [('bets', 1),
#   ('be', 1),
#   ('bast', 1),
#   ('dest', 1),
#   ('bass', 1),
#   ('beets', 1),
#   ('beat', 1),
#   ('bist', 1),
#   ('biwes', 1),
#   ('besh', 1),
#   ('besd', 1),
#   ('mest', 1),
#   ('beast', 1),
#   ('bettes', 1),
#   ('bister', 1),
#   ('bess', 1),
#   ('bes', 1),
#   ('bet', 1)],
#  'lots': [('losts', 1), ('lotes', 1), ('lot', 1), ('lost', 1)],
#  'propagates': [('propogates', 1)],
#  'score': [('skore', 1), ('scor', 1)],
#  'side': [('sied', 1), ('se', 1), ('sid', 1)],
#  'preserve': [('preseve', 1)],
#  'claws': [('clors', 1)],
#  'never': [('neve', '2'),
#   ('newer', 1),
#   ('mever', 1),
#   ('nere', 1),
#   ('nof', 1),
#   ('knver', 1),
#   ('neaver', 1),
#   ('nether', '2'),
#   ('nef', 1),
#   ('neiver', 1),
#   ('nerth', 1),
#   ('naver', 1),
#   ('nven', 1),
#   ('nese', 1),
#   ('ner', 1),
#   ('neven', 1),
#   ('nver', 1)],
#  'extend': [('exstend', 1), ('extand', 1)],
#  'nature': [('nacher', 1), ('nuture', 1), ('natior', 1), ('m', 1)],
#  'rolled': [('rolld', 1), ('rold', 1)],
#  'invigorated': [('envigorated', 1)],
#  'souvenir': [('souvenier', 1), ('suvenere', 1), ('souviner', 1)],
#  'extent': [('exstent', 1)],
#  'wheelbarrow': [('wheel_barrow', 1)],
#  'debt': [('dept', 1), ('deat', 1)],
#  'tyranny': [('tyrrany', '2'), ('tyrany', 1)],
#  'patented': [('pattented', 1)],
#  'accident': [('and', 1),
#   ('aserdent', 1),
#   ('exded', 1),
#   ('asden', 1),
#   ('sedent', 1),
#   ('acadent', 1),
#   ('ataren', 1),
#   ('axcident', 1),
#   ('askendent', 1),
#   ('castan', 1),
#   ('asdent', 1),
#   ('anitharent', 1),
#   ('esadend', 1),
#   ('a_canet', 1),
#   ('acedcedt', 1),
#   ('asde', 1),
#   ('anteght', 1),
#   ('aciddent', 1),
#   ('accicent', 1),
#   ('andandn', 1),
#   ('acciendent', 1),
#   ('aciedent', 1),
#   ('askedent', 1),
#   ('agisted', 1),
#   ('axedet', 1),
#   ('ascended', 1),
#   ('accierdent', 1),
#   ('asident', 1),
#   ('acsident', 1),
#   ('asedend', 1),
#   ('exedelt', 1),
#   ('harcent', 1),
#   ('accsident', 1),
#   ('andexns', 1),
#   ('acsdent', 1),
#   ('accend', 1),
#   ('axseadent', 1),
#   ('andet', 1),
#   ('accxident', 1),
#   ('aciadent', 1),
#   ('exiedent', 1),
#   ('axs', 1),
#   ('axerdent', 1),
#   ('advainet', 1),
#   ('exedent', 1),
#   ('andires', 1),
#   ('acsedent', 1),
#   ('andient', 1),
#   ('asadun', 1),
#   ('akcdent', 1),
#   ('acedent', 1),
#   ('axed', 1),
#   ('andint', 1),
#   ('ancident', 1),
#   ('aken', 1),
#   ('ased', 1),
#   ('asabed', 1),
#   ('acident', 1),
#   ('afanat', 1),
#   ('xedet', 1),
#   ('axedent', 1),
#   ('acist', 1),
#   ('acdent', 1),
#   ('acs', 1),
#   ('axidint', 1),
#   ('acats', 1),
#   ('asterdet', 1),
#   ('accdient', 1),
#   ('axedents', 1),
#   ('acddent', 1),
#   ('axident', 1),
#   ('addinent', 1),
#   ('acdend', 1),
#   ('accedent', 1)],
#  'chirped': [('cherped', 1)],
#  'country': [('ocuntry', 1),
#   ('carty', 1),
#   ('cout', 1),
#   ('contry', 1),
#   ('county', 1),
#   ('coontry', 1),
#   ('countrie', 1)],
#  'teddy_boy': [('teddoy', 1), ('tedeboy', '4')],
#  'incense': [('insense', 1)],
#  'levitating': [('levetating', 1)],
#  'planned': [('planed', '2')],
#  'asked': [('ask', '5'), ('askt', 1), ('arsed', '2')],
#  'unsymmetrical': [('unsyme', 1)],
#  'vain': [('vane', 1)],
#  'humming': [('huming', 1)],
#  'cardboard': [('cardbord', 1)],
#  'source': [('sorce', 1), ('aource', 1), ('sauce', 1), ('sourse', 1)],
#  'union': [('unioun', 1)],
#  'criticised': [('critisized', 1)],
#  'much': [('must', 1), ('mush', '5'), ('march', 1), ('mach', 1)],
#  'stadium': [('staydium', 1)],
#  'privilege': [('priviledge', '3'),
#   ('privlage', 1),
#   ('privelege', '2'),
#   ('privelige', '2'),
#   ('privaledge', 1),
#   ('pervieledges', 1),
#   ('prilavage', 1),
#   ('privoledge', 1),
#   ('prevelige', 1),
#   ('privilages', 1),
#   ('privielage', 1),
#   ('priviliage', 1),
#   ('previlege', 1),
#   ('prlige', 1),
#   ('privaledged', 1),
#   ('prilavge', 1),
#   ('providge', 1),
#   ('privelage', 1),
#   ('privelidge', 1),
#   ('privileged', 1),
#   ('priviladge', 1),
#   ('previllage', 1),
#   ('privieloge', 1),
#   ('priveelege', 1),
#   ('privilage', '2'),
#   ('preminage', 1),
#   ('previlage', 1),
#   ('previlidge', 1),
#   ('privalogy', 1),
#   ('privalidge', 1),
#   ('priviage', 1),
#   ('privilidged', 1),
#   ('purlgy', 1),
#   ('privledge', 1),
#   ('prividleged', 1),
#   ('privileelge', 1),
#   ('privalage', 1),
#   ('prilviage', 1),
#   ('prevelage', 1),
#   ('privialage', 1),
#   ('privilidge', 1),
#   ('privilige', 1),
#   ('prilvege', 1),
#   ('priveleage', 1),
#   ('privi', 1)],
#  'fry': [('fri', 1), ('frie', 1)],
#  'incompetent': [('incompetant', 1)],
#  'life': [('lif', 1), ('lief', 1), ('live', 1), ('lefe', 1)],
#  'spit': [('spite', 1)],
#  'eastern': [('eastren', 1)],
#  'wish': [('wich', 1), ('wis', 1), ('whish', 1)],
#  'lift': [('left', 1)],
#  'toboggan': [('talogon', 1),
#   ('tabogan', 1),
#   ('tabogen', 1),
#   ('tobbogan', 1),
#   ('tabogoon', 1),
#   ('tobagon', 1),
#   ('tobagan', 1),
#   ('tobogon', 1),
#   ('tobugon', 1),
#   ('tobogan', 1),
#   ('tobon', 1),
#   ('taboggan', 1),
#   ('tobogar', 1),
#   ('tobbogen', 1),
#   ('tobogurn', 1),
#   ('tobogn', 1),
#   ('taboog', 1),
#   ('tobaggan', 1),
#   ('tobboan', 1),
#   ('tabbogan', 1),
#   ('torbogen', 1),
#   ('conboggon', 1),
#   ('tobag', 1),
#   ('toboggen', 1),
#   ('toban', 1),
#   ('tobgen', 1),
#   ('tobogen', 1),
#   ('tabbogon', 1),
#   ('tobogane', 1),
#   ('tobacon', 1),
#   ('talbogan', 1),
#   ('tobogone', 1),
#   ('terbogen', 1)],
#  'child': [('cild', 1)],
#  'worked': [('work', 1), ('workt', 1), ('worted', 1)],
#  'spin': [('spen', 1)],
#  'skilfully': [('silfely', 1),
#   ('scilfle', 1),
#   ('strillfully', 1),
#   ('sceiful', 1),
#   ('fouale', 1),
#   ('lefle', 1),
#   ('sifle', 1),
#   ('scilfl', 1),
#   ('scillfully', 1),
#   ('skillfuly', 1),
#   ('skillverly', 1),
#   ('slhing', 1),
#   ('scearfolly', 1),
#   ('scferly', 1),
#   ('skillfel', 1),
#   ('squialy', 1),
#   ('sillaf', 1),
#   ('scilfly', 1),
#   ('sckeleft', 1),
#   ('skyillferley', 1),
#   ('saill', 1),
#   ('scify', 1),
#   ('skilfuly', 1),
#   ('silf-fele', 1),
#   ('skilfuley', 1),
#   ('silfle', 1),
#   ('clefler', 1),
#   ('silag', 1),
#   ('scillfuly', 1),
#   ('careing', 1),
#   ('skiverly', 1),
#   ('sifrle', 1),
#   ('sivle', 1),
#   ('skillforlly', 1),
#   ('skellfortly', 1),
#   ('sdillfully', 1),
#   ('skefferly', 1),
#   ('skill-fullie', 1),
#   ('skifly', 1),
#   ('skcinfulle', 1),
#   ('scifuly', 1),
#   ('skillferly', 1),
#   ('sarefully', 1),
#   ('soft', 1),
#   ('skifaly', 1),
#   ('sciferly', 1),
#   ('skilfarly', 1),
#   ('sqilferly', 1),
#   ('skinfuly', 1),
#   ('scill_filly', 1),
#   ('skelfuly', 1),
#   ('skifle', 1),
#   ('scillferle', 1),
#   ('scilfully', 1),
#   ('skillfully', 1),
#   ('scifule', 1),
#   ('cifarte', 1),
#   ('scillfley', 1),
#   ('skiffuly', 1),
#   ('scilferly', 1),
#   ('skilly', 1),
#   ('skeaferly', 1),
#   ('sall', 1),
#   ('skilfoly', 1),
#   ('sech', 1),
#   ('sillfully', 1),
#   ('skillful', 1),
#   ('shfally', 1),
#   ('skifully', 1),
#   ('scifeley', 1),
#   ('skilferly', 1),
#   ('selfer', 1),
#   ('sciverly', 1),
#   ('slikely', 1),
#   ('sclfoly', 1),
#   ('scilfuly', 1)],
#  'commerce': [('comerce', 1)],
#  'adaptations': [('adaptions', 1)],
#  'dissect': [('disect', 1)],
#  'employ': [('employe', 1), ('imploy', 1)],
#  'visit': [('visite', 1), ('viste', 1), ('vist', 1)],
#  'played': [('paly', 1), ('play', 1), ('plays', 1), ('bagt', 1)],
#  'player': [('playa', 1)],
#  'anticipating': [('antisepating', 1),
#   ('antisapiting', 1),
#   ('anticipitating', 1),
#   ('taniseapating', 1),
#   ('antispating', 1),
#   ('anticicitating', 1),
#   ('antizapating', 1),
#   ('antiscimation', 1),
#   ('antecipating', 1),
#   ('anticapate', 1),
#   ('anticipation', 1),
#   ('ancisapating', 1),
#   ('antiecpating', 1),
#   ('antisapit', 1),
#   ('anticepating', 1),
#   ('anticopening', 1),
#   ('anntisipation', 1),
#   ('antiapating', 1),
#   ('antcspating', 1),
#   ('anticpating', 1),
#   ('anticipting', 1),
#   ('anticiputed', 1),
#   ('antistipating', 1),
#   ('anntisapating', 1),
#   ('antisipainting', 1),
#   ('antiscipating', 1),
#   ('antisispating', 1),
#   ('atticpate', 1),
#   ('antisipating', 1),
#   ('antisepate', 1),
#   ('anticapting', 1),
#   ('anticipate', 1),
#   ('antasipation', 1),
#   ('anticapating', 1),
#   ('anticipateing', 1),
#   ('antisupate', 1),
#   ('antisapating', 1),
#   ('anticap', 1)],
#  'foot-and-mouth': [('footandmouth', 1), ('footanmouth', 1)],
#  'violin': [('voilion', 1), ('volin', 1), ('vioiln', 1)],
#  'oxymoron': [('oximoron', 1)],
#  'damaged': [('dagmed', 1),
#   ('damatge', 1),
#   ('dames', 1),
#   ('damiged', 1),
#   ('damge', 1),
#   ('dameaged', 1),
#   ('damidge', 1),
#   ('damidgd', 1),
#   ('damed', 1),
#   ('damanged', 1),
#   ('damised', 1),
#   ('daned', 1),
#   ('damgedid', 1),
#   ('damadge', 1),
#   ('dadge', 1),
#   ('damedged', 1),
#   ('damagd', 1),
#   ('damage', 1),
#   ('domg', 1),
#   ('daeged', 1),
#   ('depbiced', 1),
#   ('damigaigd', 1),
#   ('dammaged', 1),
#   ('daniged', 1),
#   ('demges', 1),
#   ('damged', 1),
#   ('dam', 1),
#   ('damagtd', 1),
#   ('damdend', 1),
#   ('damadged', 1),
#   ('bamaged', 1),
#   ('dmeg', 1),
#   ('dameged', 1),
#   ('ecage', 1),
#   ('danaged', 1),
#   ('dammage', 1),
#   ('damges', 1),
#   ('danmaged', 1),
#   ('damige', 1),
#   ('damigid', 1),
#   ('damedge', 1)],
#  'things': [('thigns', 1),
#   ('tings', 1),
#   ('thinks', 1),
#   ('thing', 1),
#   ('fens', 1),
#   ('thigsn', 1),
#   ('thnigs', 1),
#   ('think', '2'),
#   ('thigs', 1)],
#  'demands': [('diemands', 1)],
#  'split': [('splite', 1), ('spilt', 1)],
#  'babies': [('babyies', 1),
#   ('babis', 1),
#   ('badies', 1),
#   ('bayds', 1),
#   ('bebys', 1),
#   ('babbes', 1),
#   ('babes', 1),
#   ('babyis', 1),
#   ('babe', 1),
#   ('badys', 1),
#   ('babs', 1),
#   ('baby', 1),
#   ('bobs', 1),
#   ('babeyes', 1),
#   ('baddys', 1),
#   ('babys', '3'),
#   ('baybis', 1),
#   ('babyes', '3'),
#   ('abays', 1),
#   ('bady', 1),
#   ('baybes', 1),
#   ('dady', 1)],
#  'fairly': [('faily', 1), ('farly', 1), ('fairlu', 1)],
#  'Married': [('Marrid', 1)],
#  'typhoid': [('tifoid', 1), ('tyfoid', 1)],
#  'middle-aged': [('middle_age', 1)],
#  'supper': [('super', 1)],
#  "someone's": [('some_ones', 1)],
#  'peremptory': [('preemptory', 1)],
#  'rescinded': [('resinded', 1)],
#  'academic': [('accademic', 1), ('acedemic', 1)],
#  'subpoena': [('subpena', 1), ('sepina', 1)],
#  'form-mistress': [('formmistress', 1),
#   ('formistress', 1),
#   ('formmisstress', 1)],
#  'corporate': [('corparate', '2')],
#  'plaque': [('placque', 1)],
#  'capitol': [('capital', 1)],
#  'distribute': [('distribut', 1), ('distrubute', 1)],
#  'sleepy': [('sleppy', 1), ('sleepey', 1)],
#  'financially': [('fianancally', 1),
#   ('financial', 1),
#   ('financilly', 1),
#   ('funiluty', 1),
#   ('finatially', 1),
#   ('financely', 1),
#   ('fincially', 1),
#   ('finnancially', 1),
#   ('financialy', '2'),
#   ('finically', 1),
#   ('fininculay', 1),
#   ('fineanancely', 1),
#   ('famficay', 1),
#   ('finatually', 1),
#   ('finattioncely', 1),
#   ('finachily', 1),
#   ('finincially', 1),
#   ('finnancilly', 1),
#   ('finantially', 1),
#   ('financally', 1),
#   ('fenancialy', 1),
#   ('fimashly', 1),
#   ('finnacally', 1),
#   ('financhally', 1),
#   ('finiancle', 1),
#   ('finally', 1),
#   ('finiancially', 1),
#   ('finaciancally', 1),
#   ('finacially', 1),
#   ('financuly', 1),
#   ('fnaniancly', 1),
#   ('financeally', 1),
#   ('finnacily', 1),
#   ('finincally', 1),
#   ('financle', 1),
#   ('financel', 1),
#   ('finiancely', 1),
#   ('financly', 1),
#   ('finaitially', 1),
#   ('fananually', 1),
#   ('fianancially', 1),
#   ('financhilly', 1),
#   ('finantionally', 1),
#   ('finately', 1),
#   ('finiancally', 1),
#   ('finantually', 1),
#   ('finiancialy', 1),
#   ('finationly', 1),
#   ('finanialy', 1),
#   ('fanincally', 1),
#   ('financily', 1),
#   ('fiancially', 1),
#   ('fianicially', 1),
#   ('finitually', 1),
#   ('finaling', 1),
#   ('finacilly', 1),
#   ('fianiclly', 1),
#   ('finaily', 1),
#   ('finncually', 1),
#   ('fanacialy', 1),
#   ('financinally', 1),
#   ('financually', 1),
#   ('finnanially', 1),
#   ('finanically', 1),
#   ('finicially', 1),
#   ('finially', 1)],
#  'portrayed': [('protrayed', 1)],
#  'succeeding': [('suceeding', 1)],
#  'previous': [('previvous', 1),
#   ('preveous', 1),
#   ('previos', 1),
#   ('previus', 1)],
#  'purchased': [('perchased', 1)],
#  'sciences': [('se', 1)],
#  'old-fashioned': [('old_fashion', 1),
#   ('old_fashend', 1),
#   ('oldfashioned', 1)],
#  'had': [('hut', 1),
#   ('head', 1),
#   ('ad', 1),
#   ('han', 1),
#   ('hab', 1),
#   ('hade', '2'),
#   ('hed', 1),
#   ('add', 1),
#   ('ade', 1),
#   ('at', 1),
#   ('have', '2'),
#   ('av', 1),
#   ('has', '2'),
#   ('hat', 1),
#   ('haed', 1),
#   ('aud', 1)],
#  'thickening': [('thikning', 1)],
#  'Connecticut': [('Conneticut', 1)],
#  'obedient': [('obediant', '2'), ('obedent', 1)],
#  'innocent': [('inoscent', 1),
#   ('incensent', 1),
#   ('innoncent', 1),
#   ('innocense', 1),
#   ('inocence', 1),
#   ('insient', 1),
#   ('inosent', 1),
#   ('incouncent', 1),
#   ('inocient', 1),
#   ('inasence', 1),
#   ('Innocent', 1),
#   ('ininsit', 1),
#   ('inocience', 1),
#   ('inocent', 1),
#   ('innosent', 1),
#   ('innisit', 1),
#   ('inasent', 1),
#   ('inconnent', 1),
#   ('innocents', 1),
#   ('innonce', 1),
#   ('imisant', 1),
#   ('innocence', 1),
#   ('innacent', 1),
#   ('innicent', 1),
#   ('enocent', 1),
#   ('ennocent', 1),
#   ('innocnce', 1),
#   ('innoscent', 1),
#   ('iniscent', 1),
#   ('inoncent', 1),
#   ('inoccent', 1),
#   ('insent', 1),
#   ('innoint', 1),
#   ('innorcent', 1),
#   ('inocense', 1),
#   ('Inocent', 1)],
#  'prison': [('prisin', 1), ('pisond', 1), ('preson', 1), ('prision', 1)],
#  'has': [('hase', '2'), ('as', '4'), ('his', 1), ('hos', 1), ('have', 1)],
#  'hat': [('hot', 1)],
#  'every_time': [('everytime', 1)],
#  'good-humoured': [('good_humer', 1)],
#  'confidentially': [('confidentally', 1)],
#  'disagreement': [('dissagreement', 1)],
#  'possible': [('possibly', 1),
#   ('pissible', 1),
#   ('possable', '3'),
#   ('posible', 1)],
#  'unequivocally': [('unequivocaly', 1)],
#  'possibly': [('possably', 1), ('possiply', 1), ('possible', 1)],
#  'birth': [('berth', 1)],
#  'Missouri': [('Misouri', 1)],
#  'shadow': [('shaddow', 1), ('shodow', 1)],
#  'unique': [('uneque', 1)],
#  'occurring': [('occuring', '2')],
#  'desire': [('disire', 1)],
#  'psychological': [('psycological', 1)],
#  'remind': [('remined', 1),
#   ('remained', 1),
#   ('reminded', 1),
#   ('remond', 1),
#   ('remied', 1),
#   ('rembenes', 1),
#   ('remine', 1),
#   ('re_mind', 1),
#   ('remimed', 1),
#   ('renind', 1),
#   ('remaind', 1)],
#  'pavement': [('pathment', 1), ('pavment', 1)],
#  'steps': [('staps', 1)],
#  'malnutrition': [('manutriction', 1)],
#  'prologue': [('prolague', 1),
#   ('parlog', 1),
#   ('prologd', 1),
#   ('plolog', 1),
#   ('prolode', 1),
#   ('proloug', 1),
#   ('prolad', 1),
#   ('proloame', 1),
#   ('prolong', 1),
#   ('prlog', 1),
#   ('prologe', 1),
#   ('prolougle', 1),
#   ('browlog', 1),
#   ('prealog', 1),
#   ('prolarge', 1),
#   ('prolouge', 1),
#   ('prollog', 1),
#   ('prlock', 1),
#   ('porlong', 1),
#   ('prolog', 1)],
#  'Ithaca': [('Ihaca', 1)],
#  'misdemeanors': [('misdameanors', 1), ('misdemenors', 1)],
#  'Swedish': [('sweedish', 1)],
#  'attorney': [('arteny', 1),
#   ('erternly', 1),
#   ('erterey', 1),
#   ('entereny', 1),
#   ('entany', 1),
#   ('atury', 1),
#   ('ertany', 1),
#   ('arterny', 1),
#   ('aterna', 1),
#   ('ertiney', 1),
#   ('aterny', 1),
#   ('eneretel', 1),
#   ('aterney', 1),
#   ('erterny', 1),
#   ('entely', 1),
#   ('aterning', 1),
#   ('aturney', 1),
#   ('atterney', 1),
#   ('atorney', 1),
#   ('erterney', 1),
#   ('eterny', 1),
#   ('enterny', 1),
#   ('attaney', 1),
#   ('interne', 1),
#   ('atterny', 1),
#   ('ertenely', 1),
#   ('aturny', 1),
#   ('eterany', 1),
#   ('atternary', 1),
#   ('aturne', 1),
#   ('atturney', 1)],
#  'right': [('write', 1), ('rite', 1), ('rigth', '3')],
#  'old': [('ald', 1), ('ol', 1), ('lod', '4'), ('olf', 1)],
#  'creek': [('creak', 1)],
#  'crowd': [('croud', '2')],
#  'people': [('pople', '2'),
#   ('peaper', 1),
#   ('peepull', 1),
#   ('pleople', 1),
#   ('porle', 1),
#   ('pepo', 1),
#   ('pipoll', 1),
#   ('peiple', 1),
#   ('poeple', 1),
#   ('peapl', 1),
#   ('peps', 1),
#   ('po', 1),
#   ('peple', 1),
#   ('pecial', 1),
#   ('peopl', 1),
#   ('pepall', 1),
#   ('peropel', 1),
#   ('peopel', '2'),
#   ('peopal', 1),
#   ('pelele', 1),
#   ('pepal', 1),
#   ('peolpe', 1),
#   ('peropl', 1),
#   ('peaple', 1),
#   ('peol', 1),
#   ('pepole', 1)],
#  'crown': [('croun', 1)],
#  'insistence': [('insistance', '2')],
#  'harassment': [('harasment', 1), ('harrasment', 1)],
#  'creep': [('creap', 1)],
#  'enemies': [('emmines', 1),
#   ('enemeys', 1),
#   ('enemeies', 1),
#   ('emimies', 1),
#   ('enmenies', 1),
#   ('enameyes', 1),
#   ('enmoneys', 1),
#   ('eminies', 1),
#   ('enemes', 1),
#   ('enimes', 1),
#   ('emmies', 1),
#   ('emeny', 1),
#   ('eniemies', 1),
#   ('enimeys', 1),
#   ('enamys', 1),
#   ('enamies', 1),
#   ('enemyies', 1),
#   ('emenies', 1),
#   ('enimies', 1),
#   ('enimeies', 1),
#   ('enmies', 1),
#   ('enimeus', 1),
#   ('enemys', 1),
#   ('enemy', 1),
#   ('enanis', 1),
#   ('enimesies', 1),
#   ('ememy', 1),
#   ('emenys', 1),
#   ('enmeys', 1),
#   ('enames', 1),
#   ("enemy's", 1)],
#  "daddy's": [('dadies', 1)],
#  'for': [('fror', 1),
#   ('fur', 1),
#   ('fre', 1),
#   ('from', 1),
#   ('far', 1),
#   ('of', '3'),
#   ('fro', '2'),
#   ('fore', '4'),
#   ('four', '3'),
#   ('foir', 1),
#   ('in', 1),
#   ('forr', 1),
#   ('fon', 1),
#   ('foow', 1),
#   ('frou', 1),
#   ('or', 1),
#   ('fo', '2')],
#  'bottom': [('botem', 1),
#   ('bottem', 1),
#   ('botome', 1),
#   ('botton', '2'),
#   ('botom', 1)],
#  'fox': [('foxx', 1)],
#  'polluted': [('poluted', 1)],
#  'continue': [('contunie', 1)],
#  'periphery': [('perifery', 1)],
#  'syphilis': [('syphyllis', 1)],
#  'pollutes': [('polutes', 1)],
#  'pinched': [('picth', 1)],
#  'dinner-hours': [('dinner_hours', 1)],
#  'losing': [('loosing', '2'), ('loseing', 1), ('lossing', '2')],
#  'memorable': [('memerable', 1), ('memeroal', 1)],
#  'manufacturing': [('manufactoring', 1), ('manufaturing', 1)],
#  'dollars': [('dollers', 1)],
#  'anomalous': [('anomolous', 1), ('anomalus', 1)],
#  'recollect': [('reccollect', 1), ('recolect', 1)],
#  'despair': [('dispair', '3')],
#  'slightly': [('slighlty', 1)],
#  'raised': [('rased', 1)],
#  'Feb': [('Fab', 1)],
#  'Motorbike': [('Motor-bikes', 1)],
#  'facility': [('facilitie', 1)],
#  'honeymoon': [('honey_moon', 1), ('honymoon', 1), ('hunemoon', 1)],
#  'well-suited': [('well_suited', 1)],
#  'son': [('sun', 1)],
#  'respectable': [('respectible', 1)],
#  'consummated': [('consumated', 1)],
#  'sow': [('sew', 1)],
#  'wrap': [('rap', 1)],
#  'unambiguous': [('unabiguous', 1)],
#  'hallo': [('alloe', 1), ('halloe', 1)],
#  'altitude': [('ettalared', 1),
#   ('altutadue', 1),
#   ('atitude', 1),
#   ('actitude', 1),
#   ('altetede', 1),
#   ('intertourd', 1),
#   ('altechud', 1),
#   ('altitube', 1),
#   ('altituded', 1),
#   ('elit', 1),
#   ('outertod', 1),
#   ('alteytod', 1),
#   ('altechod', 1),
#   ('asitude', 1),
#   ('autityed', 1),
#   ('attetude', 1),
#   ('elitead', 1),
#   ('alletude', 1),
#   ('outatude', 1),
#   ('eltitude', 1),
#   ('altitud', 1),
#   ('altitub', 1),
#   ('alltitude', 1),
#   ('altechoued', 1),
#   ('outitude', 1),
#   ('outertude', 1),
#   ('atlesould', 1),
#   ('altiude', 1),
#   ('alterchood', 1),
#   ('altertude', 1),
#   ('altidud', 1),
#   ('outtide', 1),
#   ('autee', 1),
#   ('altilude', 1),
#   ('autachoot', 1),
#   ('altiertetude', 1),
#   ('atalrod', 1),
#   ('altihoched', 1),
#   ('altetud', 1),
#   ('alteturen', 1),
#   ('autridude', 1),
#   ('aoteod', 1),
#   ('alterrude', 1),
#   ('outituge', 1),
#   ('oiled', 1),
#   ('altuled', 1),
#   ('aletute', 1),
#   ('atain', 1),
#   ('atasher', 1),
#   ('outderer', 1),
#   ('elingtcewed', 1),
#   ('aboule', 1),
#   ('otchod', 1),
#   ('altude', 1),
#   ('alatetude', 1),
#   ('attitood', 1),
#   ('ata', 1),
#   ('altitued', 1),
#   ('outechut', 1),
#   ('altitob', 1),
#   ('altuide', 1),
#   ('altetude', 1),
#   ('atichood', 1),
#   ('altiuded', 1)],
#  'constantly': [('constanly', 1), ('constently', 1)],
#  'tame': [('tam', 1)],
#  'width': [('with', 1)],
#  "boy's": [('boy', '3'), ('boys', '2')],
#  'overhead': [('overhaed', 1)],
#  'happy': [('happiy', 1),
#   ('happe', 1),
#   ('happer', 1),
#   ('appey', 1),
#   ('hapr', 1),
#   ('hope', 1),
#   ('hapy', 1),
#   ('happler', 1),
#   ('happle', 1),
#   ('happi', 1),
#   ('hape', 1),
#   ('hoppe', 1),
#   ('happert', 1),
#   ('hepe', 1),
#   ('apay', 1),
#   ('h_pping', 1),
#   ('hap', 1),
#   ('happie', 1),
#   ('glad', 1),
#   ('ape', 1)],
#  'offer': [('ofer', 1)],
#  'fascination': [('fasantion', 1)],
#  'cassowary': [('cassawory', 1), ('cassowarry', 1)],
#  'talents': [('tallents', 1)],
#  'understandable': [('understadable', 1)],
#  'beech': [('beach', 1)],
#  'safeguard': [('safegaurd', 1)],
#  'congratulations': [('congratalation', 1),
#   ('congragalations', 1),
#   ('congrulations', 1),
#   ('congratulation', 1),
#   ('concradulations', 1),
#   ('congraulations', 1),
#   ('congradulation', 1),
#   ('congreation', 1),
#   ('comcerracarlants', 1),
#   ('congratulate', 1),
#   ('congratalutions', 1),
#   ('congrutulations', 1),
#   ('congralulations', 1),
#   ('congraulation', 1),
#   ('congratulatons', 1),
#   ('congralutations', 1),
#   ('congradulations', '2'),
#   ('congretulations', 1),
#   ('congraduation', 1),
#   ('congrationlation', 1),
#   ('conguralitions', 1),
#   ('congragulations', 1),
#   ('congratilations', 1),
#   ('congratualations', 1),
#   ('congraudulations', 1),
#   ('congratalations', 1),
#   ('congradualtions', 1),
#   ('congreatulations', 1),
#   ('congralutaions', 1),
#   ('congratilation', 1),
#   ('conglutation', 1),
#   ('congratrilations', 1),
#   ('congractulations', 1),
#   ('congraduations', 1),
#   ('congratuations', 1),
#   ('congratulions', 1),
#   ('congraturalations', 1),
#   ('congralation', 1),
#   ('congradutation', 1),
#   ('concrogulation', 1)],
#  'genealogy': [('geneology', 1)],
#  "else's": [('elss', 1), ('elesers', 1)],
#  'inside': [('insid', 1), ('in_sis', 1), ('in_side', '2')],
#  'equalization': [('equilisation', 1)],
#  'devices': [('def', 1)],
#  'unanimous': [('unamenous', 1),
#   ('youmanles', 1),
#   ('umamous', 1),
#   ('anonymous', 1),
#   ('unammious', 1),
#   ('unnamious', 1),
#   ('unamamous', 1),
#   ('unanumous', 1),
#   ('umanaress', 1),
#   ('eunaminus', 1),
#   ('uniamimus', 1),
#   ('unnanomous', 1),
#   ('ununumus', 1),
#   ('unanious', 1),
#   ('unninote', 1),
#   ('unonomious', 1),
#   ('unaminus', 1),
#   ('unaninous', 1),
#   ('unenamous', 1),
#   ('unoniums', 1),
#   ('unamusts', 1),
#   ('unaniae', 1),
#   ('younamenous', 1),
#   ('uniomus', 1),
#   ('unanumas', 1),
#   ('sallanous', 1),
#   ('unamuse', 1),
#   ('unanimoses', 1),
#   ('unnanimous', 1),
#   ('unmnus', 1),
#   ('younamess', 1),
#   ('unamimus', 1),
#   ('unammius', 1),
#   ('amius', 1),
#   ('unaimous', 1),
#   ('unumanious', 1),
#   ('unacious', 1),
#   ('unananois', 1),
#   ('unnambus', 1),
#   ('unanmous', 1),
#   ('unanomous', 1),
#   ('unanus', 1),
#   ('umamilus', 1),
#   ('unanamious', 1),
#   ('unaiminous', 1),
#   ('unaminuous', 1),
#   ('unaninus', 1),
#   ('inamimus', 1),
#   ('eunamous', 1),
#   ('unanonus', 1),
#   ('unamous', 1),
#   ('unamious', 1),
#   ('unnamous', 1),
# ...
#  'concentrates': [('consentrates', 1)],
#  'expression': [('expresion', 1)],
#  "can't": [("cann't", 1),
#   ('carnt', '2'),
#   ('cant', '4'),
#   ("carn't", '2'),
#   ('canth', 1)],
#  'allowance': [('allowence', 1)],
#  'yearly': [('yearley', 1)],
#  'twin': [('twen', 1)],
#  'comeback': [('comback', 1)],
#  'geese': [('gees', 1)],
#  'buoyancy': [('bouyancy', 1)],
#  'considers': [('conciders', 1)],
#  'boat': [('boaut', 1), ('bot', 1)],
#  'caring': [('careing', 1)],
#  'comb': [('come', 1)],
#  'unconsciousness': [('unconciousness', 1)],
#  'stretch': [('strech', 1), ('streach', 1)],
#  'west': [('wast', 1)],
#  'locally': [('localy', 1)],
#  'vacation': [('vakation', 1), ('vacashon', 1), ('vaction', 1)],
#  'concede': [('consede', 1)],
#  'breath': [('breathe', 1), ('breth', 1), ('brath', 1)],
#  'almighty': [('almity', 1)],
#  'practised': [('practise', 1), ('practiced', 1)],
#  'wants': [('wans', 1), ('wnats', 1), ('wantes', 1), ('want', 1)],
#  'enable': [('unable', 1), ('anable', 1)],
#  'unsafe': [('unsf', 1)],
#  'thousand': [('thousend', 1), ('thousnand', 1)],
#  'formed': [('fromed', 1), ('form', 1), ('formd', 1)],
#  'observe': [('obsirve', 1), ('obi', 1)],
#  'extant': [('extint', 1)],
#  'calligraphy': [('caligraphy', 1)],
#  'former': [('fro', 1), ('farmer', 1)],
#  'prominence': [('prominance', 1)],
#  'straighten': [('straiten', 1)],
#  'easier': [('eassier', 1),
#   ('ease', 1),
#   ('easyer', 1),
#   ('easy', 1),
#   ('easery', 1),
#   ('easer', 1)],
#  'newspaper': [('newpaper', 1), ('newspapper', 1), ('news_paper', 1)],
#  'situation': [('situration', 1), ('sitt', 1), ('situating', 1)],
#  'constituency': [('consituency', 1)],
#  'all-round': [('all_round', 1)],
#  'purse': [('purce', 1), ('perse', 1)],
#  'vandalism': [('vanderlism', 1), ('vandolism', 1), ('vanderlisium', 1)],
#  'unhygienic': [('unheigenic', 1)],
#  'barbed': [('barb', '2')],
#  'sickness': [('sicknes', 1)],
#  'I': [('a', 1),
#   ('and', 1),
#   ('ld', 1),
#   ('we', 1),
#   ('i', 1),
#   ('is', 1),
#   ('it', 1),
#   ('iy', 1),
#   ('if', 1),
#   ('are', 1),
#   ('has', 1),
#   ('he', 1)],
#  'defy': [('defie', 1)],
#  'advertisement': [('advertisment', '2')],
#  'volcanoes': [('volcanos', 1)],
#  'vacant': [('vacent', 1)],
#  'tentacle': [('tenacle', 1)],
#  'so_forth': [('soforth', 1), ('so-forth', 1)],
#  'genii': [('genei', 1)],
#  'grumpy': [('grumby', 1)],
#  'Botswana': [('botuania', 1)],
#  'summer': [('sumer', 1)],
#  'manifold': [('many_fold', 1)],
#  'being': [('bieng', 1),
#   ('be', 1),
#   ('bi', 1),
#   ('been', '2'),
#   ('bieing', 1),
#   ('beeing', 1)],
#  'truculent': [('trucculent', 1)],
#  'exaggerating': [('exagerating', 1), ('exagerrating', 1)],
#  'rest': [('rast', 1)],
#  'schools': [('school', 1), ('schol', 1)],
#  'steamer': [('stemer', 1)],
#  'omissions': [('ommissions', 1)],
#  'weekly': [('weakly', 1)],
#  'sixteen': [('sixtine', 1), ('sixten', 1)],
#  'generator': [('generrater', 1)],
#  'silver': [('siver', 1), ('sliver', 1)],
#  'instrument': [('instrement', 1),
#   ('instrment', 1),
#   ('insromet', 1),
#   ('instriment', 1)],
#  'prominently': [('prominately', 1), ('prominantly', 1)],
#  'aspects': [('spects', 1)],
#  'around': [('rand', 1),
#   ('arr', 1),
#   ('rend', 1),
#   ('a_rand', 1),
#   ('aradret', 1),
#   ('ar', 1),
#   ('a_rade', 1),
#   ('roned', 1),
#   ('arouned', 1),
#   ('ar_rounde', 1),
#   ('a_rarnd', 1),
#   ('rond', 1),
#   ('aroand', 1),
#   ('aron', 1),
#   ('aroud', 1),
#   ('arond', 1),
#   ('arround', 1),
#   ('arad', 1),
#   ('a_round', '2'),
#   ('a_rond', 1),
#   ('arode', 1),
#   ('urand', 1),
#   ('aroude', 1),
#   ('arownd', 1),
#   ('round', 1)],
#  'decomposed': [('decomposited', 1)],
#  'knobbly': [('nobbly', 1)],
#  'dart': [('tat', 1),
#   ('art', 1),
#   ('darrt', 1),
#   ('doatg', 1),
#   ('darte', 1),
#   ('derter', 1),
#   ('brt', 1),
#   ('dered', 1),
#   ('daud', 1),
#   ('yaht', 1),
#   ('dorte', 1),
#   ('dute', 1),
#   ('drate', 1),
#   ('dete', 1),
#   ('durt', 1),
#   ('daring', 1),
#   ('darolt', 1),
#   ('byt', 1),
#   ('drte', 1),
#   ('snad', 1),
#   ('daet', 1),
#   ('doath', 1),
#   ('dutr', 1),
#   ('dard', 1),
#   ('dut', 1),
#   ('dunt', 1),
#   ('tart', 1),
#   ('dae', 1),
#   ('dert', 1),
#   ('burte', 1),
#   ('dirt', 1),
#   ('dorter', 1),
#   ('deent', 1),
#   ('but', 1),
#   ('dret', 1),
#   ('dat', 1),
#   ('drek', 1),
#   ('daw', 1),
#   ('nitty', 1),
#   ('datre', 1),
#   ('deatre', 1),
#   ('date', 1),
#   ('bit', 1),
#   ('deart', 1),
#   ('drat', 1),
#   ('dater', 1),
#   ('drit', 1),
#   ('adar', 1),
#   ('derdt', 1),
#   ('drt', 1),
#   ('dared', 1),
#   ('snt', 1),
#   ('drk', 1),
#   ('dort', 1),
#   ('duit', 1),
#   ('durte', 1),
#   ('dot', 1)],
#  'dark': [('ding', 1),
#   ('duc', 1),
#   ('durk', 1),
#   ('dake', 1),
#   ('back', 1),
#   ('ducr', 1),
#   ('dia', 1),
#   ('down', 1),
#   ('drlak', 1),
#   ('dick', 1),
#   ('barck', 1),
#   ('dining', 1),
#   ('dork', 1),
#   ('dagy', 1),
#   ('drck', 1),
#   ('drak', 1),
#   ('darrk', 1),
#   ('darw', 1),
#   ('dak', 1),
#   ('dreh', 1),
#   ('brek', 1),
#   ('dare', 1),
#   ('dard', 1),
#   ('bar', 1),
#   ('drow', 1),
#   ('dog', 1),
#   ('drk', 1),
#   ('dank', 1),
#   ('bnack', 1),
#   ('darch', 1),
#   ('darck', '2'),
#   ('dir', 1)],
#  'traffic': [('travic', 1),
#   ('tacter', 1),
#   ('drafec', 1),
#   ('trafice', 1),
#   ('trafick', 1),
#   ('traffi', 1),
#   ('trofek', 1),
#   ('trafeck', 1),
#   ('tavit', 1),
#   ('trfick', 1),
#   ('traie', 1),
#   ('tatif', 1),
#   ('tiornef', 1),
#   ('tac', 1),
#   ('roads', 1),
#   ('tarnftian', 1),
#   ('peraffic', 1),
#   ('cafic', 1),
#   ('treffer', 1),
#   ('trafit', 1),
#   ('trafic', '2'),
#   ('tafic', 1),
#   ('tavek', 1),
#   ('taafic', 1),
#   ('tiatic', 1),
#   ('taame', 1),
#   ('trafack', 1),
#   ('tatlek', 1),
#   ('tafeate', 1),
#   ('traffek', 1),
#   ('trafik', 1),
#   ('traffc', 1),
#   ('trafet', 1),
#   ('traveck', 1),
#   ('track', 1),
#   ('traff', 1),
#   ('traffig', 1),
#   ('tairer', 1),
#   ('traffice', 1),
#   ('tinict', 1),
#   ('traik', 1),
#   ('travick', 1),
#   ('tracky', 1),
#   ('traifec', 1),
#   ('terrec', 1),
#   ('traffik', 1),
#   ('trafek', 1),
#   ('tarffic', 1),
#   ('taveging', 1),
#   ('tafter', 1),
#   ('taraf', 1),
#   ('craffeck', 1),
#   ('tale', 1),
#   ('tate', 1),
#   ('thaiech', 1),
#   ('farolc', 1),
#   ('trare', 1),
#   ('traph', 1),
#   ('trafec', 1)],
#  'bandage': [('bandge', 1)],
#  'vacuum': [('vaccume', 1), ('vaccum', 1)],
#  'world': [('wald', 1),
#   ('worde', 1),
#   ('word', 1),
#   ('would', 1),
#   ('wholed', 1),
#   ('wold', 1),
#   ('wourld', 1)],
#  'postal': [('postel', 1)],
#  'decomposes': [('decomposits', 1)],
#  'vague': [('vaig', 1), ('vage', 1)],
#  'dare': [('dear', 1), ('dair', 1)],
#  'satisfaction': [('shasan', 1),
#   ('satichfatshen', 1),
#   ('satisfacshoin', 1),
#   ('satisfacshion', 1),
#   ('wanat', 1),
#   ('sabfas', 1),
#   ('istis', 1),
#   ('satisfacshin', 1),
#   ('satisfashoin', 1),
#   ('satisfacsion', 1),
#   ('satfacso', 1),
#   ('sachfachn', 1),
#   ('stisfacho', 1),
#   ('satlistash', 1),
#   ('satisfacion', 1),
#   ('satesfaction', 1),
#   ('satisfation', 1),
#   ('satiusfacson', 1),
#   ('satifacian', 1),
#   ('satefasion', 1),
#   ('satisfactoin', 1),
#   ('satifoin', 1),
#   ('satishfacen', 1),
#   ('satisfaften', 1),
#   ('satfaction', 1),
#   ('sackaach', 1),
#   ('satfakess', 1),
#   ('satifactoin', 1),
#   ('saciffaction', 1),
#   ('satfacan', 1),
#   ('satisfacttion', 1),
#   ('satamachen', 1),
#   ('satishfation', 1),
#   ('silhen_fant', 1),
#   ('sacfatchen', 1),
#   ('satesfach_chere', 1),
#   ('satisfn', 1),
#   ('satirsh', 1),
#   ('siterfatur', 1),
#   ('satisfatch', 1),
#   ('eat_as_of_ede', 1),
#   ('satishfaction', 1),
#   ('satisfakshion', 1),
#   ('fian', 1),
#   ('satisfacshon', 1),
#   ('satifation', 1),
#   ('setisfate', 1),
#   ('satifachen', 1),
#   ('satishfaktion', 1),
#   ('satifishan', 1),
#   ('satitfaction', 1),
#   ('sat_oford', 1),
#   ('sartfasn', 1),
#   ('sats_fan', 1),
#   ('satisvetion', 1),
#   ('satisfacshun', 1),
#   ('satfasher', 1),
#   ('sicifaris', 1),
#   ('setitfared', 1),
#   ('sitisfaction', 1),
#   ('satisfuckshon', 1),
#   ('satishan', 1),
#   ('sat_fainand', 1),
#   ('sachen', 1),
#   ('sachfaen', 1),
#   ('statsiefacsed', 1),
#   ('argring_atoing', 1),
#   ('satigan', 1),
#   ('satichfachcen', 1),
#   ('satisfachan', 1),
#   ('satiffashon', 1),
#   ('sacisfacsh', 1),
#   ('satisfakson', 1),
#   ('satisfackshen', 1),
#   ('sackitvansh', 1),
#   ('satifaction', 1),
#   ('satifachon', 1),
#   ('satisfachen', 1),
#   ('soam', 1),
#   ('sackifsacshern', 1),
#   ('sattfashed', 1),
#   ('satsha', 1),
#   ('satifason', 1),
#   ('satispachoin', 1),
#   ('saticfacon', 1),
#   ('satisfakshon', 1),
#   ('satisfacin', 1),
#   ('call_fall', 1),
#   ('satisfcshion', 1),
#   ('satifacion', 1),
#   ('satistloin', 1),
#   ('satigaction', 1),
#   ('satisfackshon', 1),
#   ('satesfacshen', 1),
#   ('satisfachshon', 1),
#   ('satfatre', 1),
#   ('satisfain', 1)],
#  'unrepentant': [('unrepentent', 1)],
#  'nutrients': [('nutritents', 1)],
#  'souvenirs': [('souveniers', 1)],
#  'discarded': [('discare', 1)],
#  'stationary': [('stationery', 1)],
#  'clap': [('klap', 1), ('clape', 1)],
#  'auditorium': [('autorm', 1),
#   ('autoruim', 1),
#   ('auditormunen', 1),
#   ('audiatorum', 1),
#   ('auditouim', 1),
#   ('allturman', 1),
#   ('audatoreum', 1),
#   ('oratoroum', 1),
#   ('autitorium', 1),
#   ('auditorm', 1),
#   ('additorium', 1),
#   ('auditorim', 1),
#   ('autormen', 1),
#   ('allortomdd', 1),
#   ('audaterame', 1),
#   ('adutorium', 1),
#   ('auditarium', 1),
#   ('auditory', 1),
#   ('attorium', 1),
#   ('audetorium', 1),
#   ('audotorium', 1),
#   ('auditourin', 1),
#   ('auditorial', 1),
#   ('auditoriam', 1),
#   ('autorum', 1),
#   ('auditoruium', 1),
#   ('autotorium', 1),
#   ('autatorum', 1),
#   ('autatorom', 1),
#   ('adetoreum', 1),
#   ('aduoteriam', 1),
#   ('auditorinum', 1),
#   ('audatorum', 1),
#   ('auttortism', 1),
#   ('auditiorm', 1),
#   ('audortum', 1),
#   ('ouditorium', 1),
#   ('auditorum', 1),
#   ('auditoium', 1),
#   ('auditoryum', 1),
#   ('auditoriom', 1),
#   ('auditorimn', 1),
#   ('adatorum', 1),
#   ('auditorym', 1),
#   ('arudtiorze', 1),
#   ('auditormeon', 1),
#   ('auditorumen', 1),
#   ('authorium', 1),
#   ('auditoreum', 1),
#   ('ottatorium', 1),
#   ('audiotorium', 1),
#   ('autitorum', 1),
#   ('audiortium', 1),
#   ('attoram', 1),
#   ('audetorn', 1),
#   ('auditor', 1),
#   ('audatorium', 1),
#   ('audortorium', 1),
#   ('auditoriumn', 1),
#   ('aduitorum', 1),
#   ('auditoriun', 1),
#   ('aditorum', 1),
#   ('aditorium', 1)],
#  'satisfactory': [('satsfactory', 1), ('satifactory', 1), ('satisfactary', 1)],
#  'superintendent': [('superintendant', 1), ('supertendent', 1)],
#  'learning': [('learnning', 1),
#   ('learing', 1),
#   ('lerning', 1),
#   ('learining', 1)],
#  'supplementary': [('suplementary', 1)],
#  'divine': [('devin', 1),
#   ('devying', 1),
#   ('divide', 1),
#   ('deavine', 1),
#   ('devide', 1),
#   ('devine', 1),
#   ('devined', 1),
#   ('delvine', 1),
#   ('divene', 1),
#   ('define', 1)],
#  'thinks': [('thikns', 1)],
#  "there'll": [('therell', 1)],
#  'memories': [('memoirs', 1),
#   ('mearise', 1),
#   ('memeroies', 1),
#   ('momories', 1),
#   ('memerories', 1),
#   ('meherey', 1),
#   ('merrerys', 1),
#   ('memoaries', 1),
#   ('memoraries', 1),
#   ('merries', 1),
#   ('mermarys', 1),
#   ('mermories', 1),
#   ("memory's", 1),
#   ('remison', 1),
#   ('memordies', 1),
#   ('memorries', 1),
#   ('mearsise', 1),
#   ('memey', 1),
#   ('memory', 1),
#   ('memoiries', 1),
#   ('memuries', 1),
#   ('memoreys', 1),
#   ('merrors', 1),
#   ('memmories', 1),
#   ('moniiy', 1),
#   ('monorious', 1),
#   ('merories', 1),
#   ('memeris', 1),
#   ('merores', 1),
#   ('moremery', 1),
#   ('memoreres', 1),
#   ('marysis', 1),
#   ('memoryes', 1),
#   ('memorarys', 1),
#   ('memouries', 1),
#   ("memorie's", 1),
#   ('memorys', 1),
#   ('memeries', 1),
#   ('mermiores', 1),
#   ('memmorys', 1),
#   ('memerys', 1),
#   ('mamrioes', 1)],
#  'noon': [('non', 1)],
#  'endocrine': [('endochrine', 1)],
#  'refer': [('refere', 1)],
#  'unsuccessfully': [('unsucesfuly', 1), ('unsucessfully', 1)],
#  'accessing': [('accesing', 1)],
#  'scientific': [('scientic', 1), ('scienfic', 1), ('st', 1)],
#  'power': [('pwoer', 1), ('pour', 1)],
#  'intimate': [('intermit', 1)],
#  'in_spite': [('inspite', 1)],
#  'playing-field': [('playfud', 1), ('playing_field', 1), ('playfeild', 1)],
#  'stone': [('ston', 1)],
#  'package': [('packege', 1), ('pakage', 1)],
#  'disabilities': [('dissabiliteys', 1)],
#  'meal': [('mel', 1), ('mell', 1)],
#  'neighbor': [('neighbour', 1), ('neigbour', 1)],
#  'act': [('at', 1), ('akt', 1)],
#  'luck': [('lock', 1)],
#  'rabbinical': [('rabinnical', 1)],
#  'burning': [('buring', 1)],
#  'legged': [('leged', 1)],
#  'lively': [('livly', 1), ('livley', 1)],
#  'parties': [('partys', 1), ("party's", 1)],
#  'accumulated': [('acumulated', 1)],
#  'technically': [('technecally', 1), ('techniquely', 1)],
#  'burglar': [('burgler', 1), ('buglar', 1)],
#  'her': [('hir', 1),
#   ('there', 1),
#   ('them', 1),
#   ('here', '16'),
#   ('She', 1),
#   ('har', 1),
#   ('he', '4')],
#  'series': [('serious', 1)],
#  'water-rat': [('waterrat', 1)],
#  'bubble': [('buble', 1)],
#  'yearned': [('yerned', 1)],
#  'complete': [('compleat', 1)],
#  'beginners': [('begginers', 1)],
#  'elimination': [('eleimination', 1), ('elimiation', 1)],
#  'impedance': [('impedence', '2')],
#  'mice': [('mise', 1)],
#  'with': [('whin', 1),
#   ('wif', 1),
#   ('wefe', 1),
#   ('wis', '2'),
#   ('in', 1),
#   ('whit', 1),
#   ('iwth', 1),
#   ('wihth', 1),
#   ('wiy', 1),
#   ('will', 1),
#   ('what', 1),
#   ('wef', 1),
#   ('wien', 1),
#   ('when', 1),
#   ('wthe', 1),
#   ('whith', 1),
#   ('wethe', 1),
#   ('wivr', 1),
#   ('we', 1),
#   ('wihe', 1),
#   ('wh', 1),
#   ('wite', 1),
#   ('wiht', '3'),
#   ('wive', 1),
#   ('wirth', 1),
#   ('went', 1),
#   ('wtih', 1),
#   ('withe', 1),
#   ('wint', 1),
#   ('weth', 1),
#   ('wit', 1),
#   ('yethe', 1),
#   ('witht', 1),
#   ('the', 1),
#   ('wheth', 1)],
#  'buying': [('buyin', 1), ('bying', 1)],
#  'handsome': [('hansem', 1), ('hansum', 1), ('hansome', 1)],
#  "they're": [('their', 1), ('the', 1), ('there', '2'), ('thier', 1)],
#  'rush': [('ruch', 1)],
#  'monopoly': [('monapaloy', 1)],
#  'dirty': [('dertses', 1), ('diry', 1), ('driy', 1), ('durty', 1)],
#  'dispensing': [('dispencing', 1)],
#  'agree': [('agre', '2')],
#  'detailed': [('detailled', '2')],
#  'gone': [('gon', '2'),
#   ('crome', 1),
#   ('gome', 1),
#   ('goon', 1),
#   ('gonne', 1),
#   ('gornd', 1),
#   ('go', '3'),
#   ('gor', 1)],
#  'gratuitous': [('gratuitious', 1)],
#  'exhausted': [('exausted', 1), ('exhasted', 1), ('exa', 1)],
#  'certain': [('sorton', 1),
#   ('certian', 1),
#   ('surntered', 1),
#   ('sirtain', 1),
#   ('ceratin', 1),
#   ('curtain', 1),
#   ('sertain', 1),
#   ('cirtain', 1),
#   ('serton', 1)],
#  'accents': [('achsends', 1)],
#  'Cinderella': [('Cinderrella', 1)],
#  'am': [('ham', 1), ('an', 1)],
#  'an': [('a', '2'), ('and', '2'), ('un', 1), ('am', 1), ('on', 1)],
#  'as': [('ass', 1),
#   ('a', 1),
#   ('his', 1),
#   ('asw', 1),
#   ('have', 1),
#   ('was', 1),
#   ('hase', 1),
#   ('is', 1),
#   ('tes', 1),
#   ('at', 1),
#   ('aas', 1),
#   ('has', '2'),
#   ('saw', 1),
#   ('als', 1)],
#  'at': [('a', '3'),
#   ('ast', 1),
#   ('al', 1),
#   ('an', 1),
#   ('as', 1),
#   ('are', '2'),
#   ('att', 1)],
#  'hobbies': [('hobbys', 1)],
#  'creak': [('creek', 1)],
#  'cream': [('crem', 1)],
#  'ideally': [('idealy', 1)],
#  'graduate': [('graguate', 1)],
#  'tight': [('tite', 1)],
#  'Watson': [('watston', 1)],
#  'unparalleled': [('umparralled', 1),
#   ('unparralel', 1),
#   ('unparalleld', 1),
#   ('unparallelled', 1),
#   ('unparlleled', 1),
#   ('parrealled', 1),
#   ('apparrelled', 1),
#   ('unparralleled', 1),
#   ('unparreled', 1),
#   ('unparielled', 1),
#   ('empalerleld', 1),
#   ('uparrelled', 1),
#   ('unparalled', 1),
#   ('unplaled', 1),
#   ('unparlled', 1),
#   ('unparallel', 1),
#   ('anparelle', 1),
#   ('unparelled', 1),
#   ('unpall', 1),
#   ('unparrelede', 1),
#   ('un-parrallel', 1),
#   ('unblale', 1),
#   ('unparale', 1),
#   ('unperalld', 1),
#   ('unparalel', 1),
#   ('unparrowllede', 1),
#   ('unparolled', 1),
#   ('unparalelled', 1),
#   ('unparaled', 1),
#   ('unpovaly', 1),
#   ('unparralled', 1),
#   ('unparraled', 1),
#   ('unparrallel', 1),
#   ('unparrled', 1),
#   ('unpareled', 1),
#   ('unapparralled', 1),
#   ('unparraleled', 1),
#   ('unparelelled', 1),
#   ('unparrelled', 1),
#   ('unparelleled', 1),
#   ('andpiotou', 1),
#   ('unproloud', 1)],
#  'puppy': [('pupy', 1)],
#  'contemporaries': [('contamporaries', 1)],
#  'congress': [('converce', 1),
#   ('curgress', 1),
#   ('Congress', 1),
#   ('converse', 1),
#   ('Cnongress', 1),
#   ('cangress', 1),
#   ('congres', 1),
#   ('Comgress', 1),
#   ('congeres', 1)],
#  'spermatozoa': [('spermatozoan', 1)],
#  'tiger': [('tigar', 1)],
#  'partitioned': [('petitioned', 1)],
#  'mask': [('mast', 1), ('masked', 1), ('marsk', 1)],
#  'having': [('haveing', '2'), ('hvaing', 1), ('have-ing', 1), ('hower', 1)],
#  ...}

# %%
letters    = 'abcdefghijklmnopqrstuvwxyz'
cm_Substitution = [[0 for i in range(len(letters))] for j in range(len(letters))]
testDict = {'raining': [('rainning', 1)]}
testDict['raining']
# Out:
# [('rainning', 1)]

# %%
corpus2 = ''
for ch in corpus.replace('--',' '):
    if(ch.isalpha() or ch == ' ' or ch.isnumeric()):
        corpus2+=ch
    else:
        corpus2+=' '

# %%
corpus2
# Out:
# 'the project gutenberg ebook of the adventures of sherlock holmes by sir arthur conan doyle   15 in our series by sir arthur conan doyle   copyright laws are changing all over the world  be sure to check the copyright laws for your country before downloading or redistributing this or any other project gutenberg ebook   this header should be the first thing seen when viewing this project gutenberg file   please do not remove it   do not change or edit the header without written permission   please read the  legal small print   and other information about the ebook and project gutenberg at the bottom of this file   included is important information about your specific rights and restrictions in how the file may be used   you can also find out about how to make a donation to project gutenberg  and how to get involved      welcome to the world of free plain vanilla electronic texts      ebooks readable by both humans and by computers  since 1971         these ebooks were prepared by thousands of volunteers         title  the adventures of sherlock holmes  author  sir arthur conan doyle  release date  march  1999   ebook  1661   most recently updated  november 29  2002   edition  12  language  english  character set encoding  ascii      start of the project gutenberg ebook  the adventures of sherlock holmes          additional editing by jose menendez     the adventures of sherlock holmes  by  sir arthur conan doyle  contents  i  a scandal in bohemia ii  the red headed league iii  a case of identity iv  the boscombe valley mystery v  the five orange pips vi  the man with the twisted lip vii  the adventure of the blue carbuncle viii  the adventure of the speckled band ix  the adventure of the engineer s thumb x  the adventure of the noble bachelor xi  the adventure of the beryl coronet xii  the adventure of the copper beeches   adventure  i   a scandal in bohemia  i    to sherlock holmes she is always the woman  i have seldom heard him mention her under any other name  in his eyes she eclipses and predominates the whole of her sex  it was not that he felt any emotion akin to love for irene adler  all emotions  and that one particularly  were abhorrent to his cold  precise but admirably balanced mind  he was  i take it  the most perfect reasoning and observing machine that the world has seen  but as a lover he would have placed himself in a false position  he never spoke of the softer passions  save with a gibe and a sneer  they were admirable things for the observer excellent for drawing the veil from men s motives and actions  but for the trained reasoner to admit such intrusions into his own delicate and finely adjusted temperament was to introduce a distracting factor which might throw a doubt upon all his mental results  grit in a sensitive instrument  or a crack in one of his own high power lenses  would not be more disturbing than a strong emotion in a nature such as his  and yet there was but one woman to him  and that woman was the late irene adler  of dubious and questionable memory   i had seen little of holmes lately  my marriage had drifted us away from each other  my own complete happiness  and the home centred interests which rise up around the man who first finds himself master of his own establishment  were sufficient to absorb all my attention  while holmes  who loathed every form of society with his whole bohemian soul  remained in our lodgings in baker street  buried among his old books  and alternating from week to week between cocaine and ambition  the drowsiness of the drug  and the fierce energy of his own keen nature  he was still  as ever  deeply attracted by the study of crime  and occupied his immense faculties and extraordinary powers of observation in following out those clues  and clearing up those mysteries which had been abandoned as hopeless by the official police  from time to time i heard some vague account of his doings  of his summons to odessa in the case of the trepoff murder  of his clearing u ...

# %%
word_list=re.split('\s+',corpus2)

# %%
numTokens = len(word_list)
print("Number of tokens: %d" %numTokens)
# Out:
# Number of tokens: 3390

# %%
df = pd.DataFrame({'word':[],'freq':[],'percentage':[]})

# %%
wordFreq = []
for word in set(word_list):
    count = word_list.count(word)
    wordFreq.append([word, count, round(count/numTokens,5)])
wordFreq = sorted(wordFreq, key=lambda tup: tup[2], reverse=True)
df = pd.DataFrame(wordFreq, columns=['word','count','percentage'])

# %%
#df.sort_values('percentage', ascending=False)
df.head(50)
# Out:
#       word  count  percentage
# 0      the    162     0.04779
# 1       of    110     0.03245
# 2      and     96     0.02832
# 3        a     91     0.02684
# 4       to     87     0.02566
# 5        i     85     0.02507
# 6      his     59     0.01740
# 7      you     53     0.01563
# 8       in     50     0.01475
# 9       it     46     0.01357
# 10      he     44     0.01298
# 11    that     39     0.01150
# 12     was     38     0.01121
# 13      is     35     0.01032
# 14      my     31     0.00914
# 15    with     29     0.00855
# 16    have     27     0.00796
# 17   which     26     0.00767
# 18     not     26     0.00767
# 19  holmes     25     0.00737
# 20      be     25     0.00737
# 21    your     21     0.00619
# 22    this     20     0.00590
# 23      by     20     0.00590
# 24     had     20     0.00590
# 25      at     19     0.00560
# 26      as     19     0.00560
# 27    from     19     0.00560
# 28     for     18     0.00531
# 29      me     17     0.00501
# 30     but     17     0.00501
# 31    said     17     0.00501
# 32      do     15     0.00442
# 33     who     15     0.00442
# 34    upon     14     0.00413
# 35     how     14     0.00413
# 36    been     13     0.00383
# 37     are     13     0.00383
# 38      so     12     0.00354
# 39      or     12     0.00354
# 40   there     12     0.00354
# 41     one     12     0.00354
# 42     may     11     0.00324
# 43      up     11     0.00324
# 44     all     11     0.00324
# 45    then     11     0.00324
# 46     own     10     0.00295
# 47      if      9     0.00265
# 48     her      9     0.00265
# 49      an      9     0.00265

# %%
count = 0
for elem in df.itertuples(index=True, name='Pandas'):
    if(not getattr(elem, "word").isalnum()):
        count+=1
        print(getattr(elem, "word"))

# %%
count
# Out:
# 0

# %%
wordFreq
# Out:
# [['the', 162, 0.04779],
#  ['of', 110, 0.03245],
#  ['and', 96, 0.02832],
#  ['a', 91, 0.02684],
#  ['to', 87, 0.02566],
#  ['i', 85, 0.02507],
#  ['his', 59, 0.0174],
#  ['you', 53, 0.01563],
#  ['in', 50, 0.01475],
#  ['it', 46, 0.01357],
#  ['he', 44, 0.01298],
#  ['that', 39, 0.0115],
#  ['was', 38, 0.01121],
#  ['is', 35, 0.01032],
#  ['my', 31, 0.00914],
#  ['with', 29, 0.00855],
#  ['have', 27, 0.00796],
#  ['which', 26, 0.00767],
#  ['not', 26, 0.00767],
#  ['holmes', 25, 0.00737],
#  ['be', 25, 0.00737],
#  ['your', 21, 0.00619],
#  ['this', 20, 0.0059],
#  ['by', 20, 0.0059],
#  ['had', 20, 0.0059],
#  ['at', 19, 0.0056],
#  ['as', 19, 0.0056],
#  ['from', 19, 0.0056],
#  ['for', 18, 0.00531],
#  ['me', 17, 0.00501],
#  ['but', 17, 0.00501],
#  ['said', 17, 0.00501],
#  ['do', 15, 0.00442],
#  ['who', 15, 0.00442],
#  ['upon', 14, 0.00413],
#  ['how', 14, 0.00413],
#  ['been', 13, 0.00383],
#  ['are', 13, 0.00383],
#  ['so', 12, 0.00354],
#  ['or', 12, 0.00354],
#  ['there', 12, 0.00354],
#  ['one', 12, 0.00354],
#  ['may', 11, 0.00324],
#  ['up', 11, 0.00324],
#  ['all', 11, 0.00324],
#  ['then', 11, 0.00324],
#  ['own', 10, 0.00295],
#  ['if', 9, 0.00265],
#  ['her', 9, 0.00265],
#  ['an', 9, 0.00265],
#  ['man', 9, 0.00265],
#  ['has', 9, 0.00265],
#  ['no', 8, 0.00236],
#  ['eyes', 8, 0.00236],
#  ['very', 8, 0.00236],
#  ['our', 8, 0.00236],
#  ['were', 8, 0.00236],
#  ['she', 8, 0.00236],
#  ['paper', 8, 0.00236],
#  ['would', 7, 0.00206],
#  ['down', 7, 0.00206],
#  ['what', 7, 0.00206],
#  ['adventure', 7, 0.00206],
#  ['could', 7, 0.00206],
#  ['case', 7, 0.00206],
#  ['see', 7, 0.00206],
#  ['am', 7, 0.00206],
#  ['other', 6, 0.00177],
#  ['seen', 6, 0.00177],
#  ['must', 6, 0.00177],
#  ['on', 6, 0.00177],
#  ['indeed', 6, 0.00177],
#  ['out', 6, 0.00177],
#  ['some', 6, 0.00177],
#  ['note', 6, 0.00177],
#  ['him', 6, 0.00177],
#  ['gutenberg', 6, 0.00177],
#  ['most', 6, 0.00177],
#  ['bohemia', 6, 0.00177],
#  ['majesty', 6, 0.00177],
#  ['project', 6, 0.00177],
#  ['german', 6, 0.00177],
#  ['little', 6, 0.00177],
#  ['should', 6, 0.00177],
#  ['into', 6, 0.00177],
#  ['we', 6, 0.00177],
#  ['once', 5, 0.00147],
#  ['over', 5, 0.00147],
#  ['both', 5, 0.00147],
#  ['now', 5, 0.00147],
#  ['mask', 5, 0.00147],
#  ['himself', 5, 0.00147],
#  ['know', 5, 0.00147],
#  ['remarked', 5, 0.00147],
#  ['such', 5, 0.00147],
#  ['yet', 5, 0.00147],
#  ['ebook', 5, 0.00147],
#  ['matter', 5, 0.00147],
#  ['looked', 5, 0.00147],
#  ['can', 5, 0.00147],
#  ['person', 5, 0.00147],
#  ['before', 5, 0.00147],
#  ['more', 5, 0.00147],
#  ['sherlock', 5, 0.00147],
#  ['without', 5, 0.00147],
#  ['doyle', 4, 0.00118],
#  ['us', 4, 0.00118],
#  ['quite', 4, 0.00118],
#  ['small', 4, 0.00118],
#  ['adventures', 4, 0.00118],
#  ['about', 4, 0.00118],
#  ['understand', 4, 0.00118],
#  ['face', 4, 0.00118],
#  ['heard', 4, 0.00118],
#  ['none', 4, 0.00118],
#  ['will', 4, 0.00118],
#  ['t', 4, 0.00118],
#  ['visitor', 4, 0.00118],
#  ['name', 4, 0.00118],
#  ['armchair', 4, 0.00118],
#  ['written', 4, 0.00118],
#  ['watson', 4, 0.00118],
#  ['when', 4, 0.00118],
#  ['king', 4, 0.00118],
#  ['again', 4, 0.00118],
#  ['just', 4, 0.00118],
#  ['sir', 4, 0.00118],
#  ['s', 4, 0.00118],
#  ['these', 4, 0.00118],
#  ['arthur', 4, 0.00118],
#  ['conan', 4, 0.00118],
#  ['doubt', 4, 0.00118],
#  ['well', 4, 0.00118],
#  ['address', 4, 0.00118],
#  ['gentleman', 4, 0.00118],
#  ['since', 4, 0.00118],
#  ['mind', 3, 0.00088],
#  ['any', 3, 0.00088],
#  ['make', 3, 0.00088],
#  ['hand', 3, 0.00088],
#  ['much', 3, 0.00088],
#  ['while', 3, 0.00088],
#  ['time', 3, 0.00088],
#  ['aware', 3, 0.00088],
#  ['room', 3, 0.00088],
#  ['g', 3, 0.00088],
#  ['across', 3, 0.00088],
#  ['part', 3, 0.00088],
#  ['five', 3, 0.00088],
#  ['photograph', 3, 0.00088],
#  ['facts', 3, 0.00088],
#  ['file', 3, 0.00088],
#  ['made', 3, 0.00088],
#  ['strong', 3, 0.00088],
#  ['information', 3, 0.00088],
#  ['irene', 3, 0.00088],
#  ['many', 3, 0.00088],
#  ['young', 3, 0.00088],
#  ['great', 3, 0.00088],
#  ['doctor', 3, 0.00088],
#  ['help', 3, 0.00088],
#  ['account', 3, 0.00088],
#  ['take', 3, 0.00088],
#  ['heavy', 3, 0.00088],
#  ['country', 3, 0.00088],
#  ['world', 3, 0.00088],
#  ['von', 3, 0.00088],
#  ['always', 3, 0.00088],
#  ['europe', 3, 0.00088],
#  ['ha', 3, 0.00088],
#  ['bought', 3, 0.00088],
#  ['those', 3, 0.00088],
#  ['practice', 3, 0.00088],
#  ['six', 3, 0.00088],
#  ['hum', 3, 0.00088],
#  ['deduce', 3, 0.00088],
#  ['letters', 3, 0.00088],
#  ['friend', 3, 0.00088],
#  ['deep', 3, 0.00088],
#  ['whole', 3, 0.00088],
#  ['every', 3, 0.00088],
#  ['adler', 3, 0.00088],
#  ['bohemian', 3, 0.00088],
#  ['think', 3, 0.00088],
#  ['years', 3, 0.00088],
#  ['good', 3, 0.00088],
#  ['where', 3, 0.00088],
#  ['saw', 3, 0.00088],
#  ['here', 3, 0.00088],
#  ['importance', 3, 0.00088],
#  ['twice', 3, 0.00088],
#  ['blue', 3, 0.00088],
#  ['hardly', 3, 0.00088],
#  ['go', 3, 0.00088],
#  ['wrote', 3, 0.00088],
#  ['scandal', 3, 0.00088],
#  ['right', 3, 0.00088],
#  ['woman', 3, 0.00088],
#  ['agent', 3, 0.00088],
#  ['myself', 3, 0.00088],
#  ['say', 3, 0.00088],
#  ['murmured', 3, 0.00088],
#  ['count', 2, 0.00059],
#  ['chair', 2, 0.00059],
#  ['their', 2, 0.00059],
#  ['warsaw', 2, 0.00059],
#  ['delicate', 2, 0.00059],
#  ['powers', 2, 0.00059],
#  ['pair', 2, 0.00059],
#  ['lip', 2, 0.00059],
#  ['process', 2, 0.00059],
#  ['sound', 2, 0.00059],
#  ['came', 2, 0.00059],
#  ['entered', 2, 0.00059],
#  ['seriously', 2, 0.00059],
#  ['remove', 2, 0.00059],
#  ['home', 2, 0.00059],
#  ['work', 2, 0.00059],
#  ['seven', 2, 0.00059],
#  ['please', 2, 0.00059],
#  ['night', 2, 0.00059],
#  ['stands', 2, 0.00059],
#  ['black', 2, 0.00059],
#  ['asked', 2, 0.00059],
#  ['first', 2, 0.00059],
#  ['seldom', 2, 0.00059],
#  ['p', 2, 0.00059],
#  ['hereditary', 2, 0.00059],
#  ['word', 2, 0.00059],
#  ['adjusted', 2, 0.00059],
#  ['still', 2, 0.00059],
#  ['precisely', 2, 0.00059],
#  ['observe', 2, 0.00059],
#  ['baker', 2, 0.00059],
#  ['yes', 2, 0.00059],
#  ['kindly', 2, 0.00059],
#  ['between', 2, 0.00059],
#  ['steps', 2, 0.00059],
#  ['threw', 2, 0.00059],
#  ['men', 2, 0.00059],
#  ['problem', 2, 0.00059],
#  ['crown', 2, 0.00059],
#  ['chamber', 2, 0.00059],
#  ['immense', 2, 0.00059],
#  ['broad', 2, 0.00059],
#  ['pooh', 2, 0.00059],
#  ['data', 2, 0.00059],
#  ['companion', 2, 0.00059],
#  ['than', 2, 0.00059],
#  ['legal', 2, 0.00059],
#  ['way', 2, 0.00059],
#  ['knew', 2, 0.00059],
#  ['study', 2, 0.00059],
#  ['too', 2, 0.00059],
#  ['honour', 2, 0.00059],
#  ['against', 2, 0.00059],
#  ['yourself', 2, 0.00059],
#  ['answered', 2, 0.00059],
#  ['lately', 2, 0.00059],
#  ['theories', 2, 0.00059],
#  ['only', 2, 0.00059],
#  ['comes', 2, 0.00059],
#  ['ago', 2, 0.00059],
#  ['pray', 2, 0.00059],
#  ['keen', 2, 0.00059],
#  ['thing', 2, 0.00059],
#  ['emotion', 2, 0.00059],
#  ['getting', 2, 0.00059],
#  ['header', 2, 0.00059],
#  ['character', 2, 0.00059],
#  ['pay', 2, 0.00059],
#  ['double', 2, 0.00059],
#  ['particularly', 2, 0.00059],
#  ['told', 2, 0.00059],
#  ['interested', 2, 0.00059],
#  ['thick', 2, 0.00059],
#  ['reasoning', 2, 0.00059],
#  ['spoken', 2, 0.00059],
#  ['received', 2, 0.00059],
#  ['itself', 2, 0.00059],
#  ['client', 2, 0.00059],
#  ['did', 2, 0.00059],
#  ['reasoner', 2, 0.00059],
#  ['copyright', 2, 0.00059],
#  ['stolen', 2, 0.00059],
#  ['read', 2, 0.00059],
#  ['call', 2, 0.00059],
#  ['shown', 2, 0.00059],
#  ['mystery', 2, 0.00059],
#  ['let', 2, 0.00059],
#  ['shoulders', 2, 0.00059],
#  ['under', 2, 0.00059],
#  ['half', 2, 0.00059],
#  ['power', 2, 0.00059],
#  ['nature', 2, 0.00059],
#  ['akin', 2, 0.00059],
#  ['singular', 2, 0.00059],
#  ['beryl', 2, 0.00059],
#  ['imagine', 2, 0.00059],
#  ['moment', 2, 0.00059],
#  ['sharp', 2, 0.00059],
#  ['bell', 2, 0.00059],
#  ['clearing', 2, 0.00059],
#  ['strange', 2, 0.00059],
#  ['title', 2, 0.00059],
#  ['returned', 2, 0.00059],
#  ['reigning', 2, 0.00059],
#  ['tell', 2, 0.00059],
#  ['observed', 2, 0.00059],
#  ['whom', 2, 0.00059],
#  ['laws', 2, 0.00059],
#  ['deduction', 2, 0.00059],
#  ['extraordinary', 2, 0.00059],
#  ['brown', 2, 0.00059],
#  ['things', 2, 0.00059],
#  ['also', 2, 0.00059],
#  ['continued', 2, 0.00059],
#  ['give', 2, 0.00059],
#  ['spoke', 2, 0.00059],
#  ['marriage', 2, 0.00059],
#  ['week', 2, 0.00059],
#  ['english', 2, 0.00059],
#  ['never', 2, 0.00059],
#  ['figure', 2, 0.00059],
#  ['quarters', 2, 0.00059],
#  ['cigarette', 2, 0.00059],
#  ['london', 2, 0.00059],
#  ['enough', 2, 0.00059],
#  ['peculiar', 2, 0.00059],
#  ['hat', 2, 0.00059],
#  ['chest', 2, 0.00059],
#  ['new', 2, 0.00059],
#  ['house', 2, 0.00059],
#  ['long', 2, 0.00059],
#  ['might', 2, 0.00059],
#  ['fail', 2, 0.00059],
#  ['each', 2, 0.00059],
#  ['come', 2, 0.00059],
#  ['high', 2, 0.00059],
#  ['large', 2, 0.00059],
#  ['march', 2, 0.00059],
#  ['ormstein', 2, 0.00059],
#  ['frequently', 2, 0.00059],
#  ['drug', 2, 0.00059],
#  ['suit', 2, 0.00059],
#  ['why', 2, 0.00059],
#  ['attention', 2, 0.00059],
#  ['manner', 2, 0.00059],
#  ['better', 2, 0.00059],
#  ['dear', 2, 0.00059],
#  ['dark', 2, 0.00059],
#  ['two', 2, 0.00059],
#  ['bad', 2, 0.00059],
#  ['pushed', 2, 0.00059],
#  ['rich', 2, 0.00059],
#  ['back', 2, 0.00059],
#  ['hands', 2, 0.00059],
#  ['door', 2, 0.00059],
#  ['consult', 2, 0.00059],
#  ['writing', 2, 0.00059],
#  ['street', 2, 0.00059],
#  ['they', 2, 0.00059],
#  ['ebooks', 2, 0.00059],
#  ['rooms', 2, 0.00059],
#  ['eagerly', 1, 0.00029],
#  ['fashion', 1, 0.00029],
#  ['hence', 1, 0.00029],
#  ['nice', 1, 0.00029],
#  ['shared', 1, 0.00029],
#  ['simplicity', 1, 0.00029],
#  ['gazetteer', 1, 0.00029],
#  ['release', 1, 0.00029],
#  ['purposes', 1, 0.00029],
#  ['glance', 1, 0.00029],
#  ['egria', 1, 0.00029],
#  ['completed', 1, 0.00029],
#  ['uncertain', 1, 0.00029],
#  ['scraped', 1, 0.00029],
#  ['false', 1, 0.00029],
#  ['hour', 1, 0.00029],
#  ['electronic', 1, 0.00029],
#  ['saxe', 1, 0.00029],
#  ['brothers', 1, 0.00029],
#  ['observing', 1, 0.00029],
#  ['hold', 1, 0.00029],
#  ['through', 1, 0.00029],
#  ['plainly', 1, 0.00029],
#  ['wilhelm', 1, 0.00029],
#  ['murder', 1, 0.00029],
#  ['intrusions', 1, 0.00029],
#  ['readers', 1, 0.00029],
#  ['often', 1, 0.00029],
#  ['visit', 1, 0.00029],
#  ['crack', 1, 0.00029],
#  ['journey', 1, 0.00029],
#  ['fire', 1, 0.00029],
#  ['wanted', 1, 0.00029],
#  ['promises', 1, 0.00029],
#  ['secured', 1, 0.00029],
#  ['intended', 1, 0.00029],
#  ['glanced', 1, 0.00029],
#  ['produce', 1, 0.00029],
#  ['welcome', 1, 0.00029],
#  ['boscombe', 1, 0.00029],
#  ['former', 1, 0.00029],
#  ['services', 1, 0.00029],
#  ['print', 1, 0.00029],
#  ['desire', 1, 0.00029],
#  ['attempts', 1, 0.00029],
#  ['ridiculously', 1, 0.00029],
#  ['obviously', 1, 0.00029],
#  ['inside', 1, 0.00029],
#  ['ransacked', 1, 0.00029],
#  ['contents', 1, 0.00029],
#  ['centuries', 1, 0.00029],
#  ['quarter', 1, 0.00029],
#  ['compromising', 1, 0.00029],
#  ['problems', 1, 0.00029],
#  ['brooch', 1, 0.00029],
#  ['secreted', 1, 0.00029],
#  ['passed', 1, 0.00029],
#  ['computers', 1, 0.00029],
#  ['employing', 1, 0.00029],
#  ['tops', 1, 0.00029],
#  ['lothman', 1, 0.00029],
#  ['amiss', 1, 0.00029],
#  ['sure', 1, 0.00029],
#  ['brougham', 1, 0.00029],
#  ['step', 1, 0.00029],
#  ['authenticity', 1, 0.00029],
#  ['its', 1, 0.00029],
#  ['begin', 1, 0.00029],
#  ['familiar', 1, 0.00029],
#  ['instead', 1, 0.00029],
#  ['observation', 1, 0.00029],
#  ['death', 1, 0.00029],
#  ['retired', 1, 0.00029],
#  ['memory', 1, 0.00029],
#  ['vii', 1, 0.00029],
#  ['form', 1, 0.00029],
#  ['distinction', 1, 0.00029],
#  ['restrictions', 1, 0.00029],
#  ['actions', 1, 0.00029],
#  ['tinted', 1, 0.00029],
#  ['best', 1, 0.00029],
#  ['sign', 1, 0.00029],
#  ['glad', 1, 0.00029],
#  ['royal', 1, 0.00029],
#  ['russian', 1, 0.00029],
#  ['specific', 1, 0.00029],
#  ['appears', 1, 0.00029],
#  ['parallel', 1, 0.00029],
#  ['walks', 1, 0.00029],
#  ['nothing', 1, 0.00029],
#  ['dress', 1, 0.00029],
#  ['spare', 1, 0.00029],
#  ['resolution', 1, 0.00029],
#  ['wife', 1, 0.00029],
#  ['sufficient', 1, 0.00029],
#  ['admirably', 1, 0.00029],
#  ['sneer', 1, 0.00029],
#  ['engineer', 1, 0.00029],
#  ['verbs', 1, 0.00029],
#  ['consulting', 1, 0.00029],
#  ['state', 1, 0.00029],
#  ['married', 1, 0.00029],
#  ['appearance', 1, 0.00029],
#  ['times', 1, 0.00029],
#  ['firelight', 1, 0.00029],
#  ['point', 1, 0.00029],
#  ['incorrigible', 1, 0.00029],
#  ['believe', 1, 0.00029],
#  ['biography', 1, 0.00029],
#  ['volume', 1, 0.00029],
#  ['finds', 1, 0.00029],
#  ['clear', 1, 0.00029],
#  ['whistled', 1, 0.00029],
#  ['twentieth', 1, 0.00029],
#  ['interests', 1, 0.00029],
#  ['fishes', 1, 0.00029],
#  ['carelessly', 1, 0.00029],
#  ['noble', 1, 0.00029],
#  ['dull', 1, 0.00029],
#  ['remarkable', 1, 0.00029],
#  ['away', 1, 0.00029],
#  ['cloud', 1, 0.00029],
#  ['operatic', 1, 0.00029],
#  ['secrecy', 1, 0.00029],
#  ['carried', 1, 0.00029],
#  ['motives', 1, 0.00029],
#  ['press', 1, 0.00029],
#  ['buried', 1, 0.00029],
#  ['obstinacy', 1, 0.00029],
#  ['1858', 1, 0.00029],
#  ['clasped', 1, 0.00029],
#  ['grit', 1, 0.00029],
#  ['effusive', 1, 0.00029],
#  ['thought', 1, 0.00029],
#  ['o', 1, 0.00029],
#  ['rather', 1, 0.00029],
#  ['being', 1, 0.00029],
#  ['appeared', 1, 0.00029],
#  ['extreme', 1, 0.00029],
#  ['wet', 1, 0.00029],
#  ['lived', 1, 0.00029],
#  ['scene', 1, 0.00029],
#  ['calves', 1, 0.00029],
#  ['coat', 1, 0.00029],
#  ['recovered', 1, 0.00029],
#  ['ground', 1, 0.00029],
#  ['gibe', 1, 0.00029],
#  ['passage', 1, 0.00029],
#  ['family', 1, 0.00029],
#  ['examined', 1, 0.00029],
#  ['uncontrollable', 1, 0.00029],
#  ['notice', 1, 0.00029],
#  ['imitated', 1, 0.00029],
#  ['confess', 1, 0.00029],
#  ['trifle', 1, 0.00029],
#  ['merely', 1, 0.00029],
#  ['nitrate', 1, 0.00029],
#  ['feet', 1, 0.00029],
#  ['outside', 1, 0.00029],
#  ['private', 1, 0.00029],
#  ['balanced', 1, 0.00029],
#  ['signs', 1, 0.00029],
#  ['wishes', 1, 0.00029],
#  ['ii', 1, 0.00029],
#  ['peculiarly', 1, 0.00029],
#  ['adventuress', 1, 0.00029],
#  ['difficult', 1, 0.00029],
#  ['adopted', 1, 0.00029],
#  ['1888', 1, 0.00029],
#  ['trimmed', 1, 0.00029],
#  ['walk', 1, 0.00029],
#  ['resolve', 1, 0.00029],
#  ['strongly', 1, 0.00029],
#  ['throwing', 1, 0.00029],
#  ['reopened', 1, 0.00029],
#  ['precise', 1, 0.00029],
#  ['interesting', 1, 0.00029],
#  ['lying', 1, 0.00029],
#  ['boot', 1, 0.00029],
#  ['volunteers', 1, 0.00029],
#  ['harness', 1, 0.00029],
#  ['hot', 1, 0.00029],
#  ['addressing', 1, 0.00029],
#  ['led', 1, 0.00029],
#  ['downloading', 1, 0.00029],
#  ['temperament', 1, 0.00029],
#  ['baffled', 1, 0.00029],
#  ['wheels', 1, 0.00029],
#  ['instance', 1, 0.00029],
#  ['put', 1, 0.00029],
#  ['discover', 1, 0.00029],
#  ['vile', 1, 0.00029],
#  ['reproachfully', 1, 0.00029],
#  ['remembered', 1, 0.00029],
#  ['round', 1, 0.00029],
#  ['someone', 1, 0.00029],
#  ['stethoscope', 1, 0.00029],
#  ['red', 1, 0.00029],
#  ['encoding', 1, 0.00029],
#  ['trincomalee', 1, 0.00029],
#  ['mess', 1, 0.00029],
#  ['prefers', 1, 0.00029],
#  ['faculties', 1, 0.00029],
#  ['burned', 1, 0.00029],
#  ['delicacy', 1, 0.00029],
#  ['emotions', 1, 0.00029],
#  ['pacing', 1, 0.00029],
#  ['deeply', 1, 0.00029],
#  ['vague', 1, 0.00029],
#  ['insane', 1, 0.00029],
#  ['among', 1, 0.00029],
#  ['observer', 1, 0.00029],
#  ['trained', 1, 0.00029],
#  ['complete', 1, 0.00029],
#  ['yours', 1, 0.00029],
#  ['sparkled', 1, 0.00029],
#  ['chin', 1, 0.00029],
#  ['agitation', 1, 0.00029],
#  ['oh', 1, 0.00029],
#  ['sell', 1, 0.00029],
#  ['ascii', 1, 0.00029],
#  ['duke', 1, 0.00029],
#  ['forehead', 1, 0.00029],
#  ['compromised', 1, 0.00029],
#  ['presumably', 1, 0.00029],
#  ['given', 1, 0.00029],
#  ['seized', 1, 0.00029],
#  ['nervous', 1, 0.00029],
#  ['ambition', 1, 0.00029],
#  ['opera', 1, 0.00029],
#  ['inches', 1, 0.00029],
#  ['save', 1, 0.00029],
#  ['activity', 1, 0.00029],
#  ['happiness', 1, 0.00029],
#  ['thursday', 1, 0.00029],
#  ['maker', 1, 0.00029],
#  ['remains', 1, 0.00029],
#  ['boots', 1, 0.00029],
#  ['opulence', 1, 0.00029],
#  ['attracted', 1, 0.00029],
#  ['eg', 1, 0.00029],
#  ['energetic', 1, 0.00029],
#  ['impatiently', 1, 0.00029],
#  ['corner', 1, 0.00029],
#  ['extended', 1, 0.00029],
#  ['apparent', 1, 0.00029],
#  ['like', 1, 0.00029],
#  ['readable', 1, 0.00029],
#  ['establishment', 1, 0.00029],
#  ['mad', 1, 0.00029],
#  ['beeches', 1, 0.00029],
#  ['alternating', 1, 0.00029],
#  ['v', 1, 0.00029],
#  ['either', 1, 0.00029],
#  ['born', 1, 0.00029],
#  ['attempt', 1, 0.00029],
#  ['houses', 1, 0.00029],
#  ['pity', 1, 0.00029],
#  ['suits', 1, 0.00029],
#  ['viii', 1, 0.00029],
#  ['marked', 1, 0.00029],
#  ['menendez', 1, 0.00029],
#  ['around', 1, 0.00029],
#  ['present', 1, 0.00029],
#  ['cried', 1, 0.00029],
#  ['daughter', 1, 0.00029],
#  ['chuckled', 1, 0.00029],
#  ['burglars', 1, 0.00029],
#  ['centred', 1, 0.00029],
#  ['check', 1, 0.00029],
#  ['recent', 1, 0.00029],
#  ['show', 1, 0.00029],
#  ['daily', 1, 0.00029],
#  ['sex', 1, 0.00029],
#  ['richness', 1, 0.00029],
#  ['until', 1, 0.00029],
#  ['cloak', 1, 0.00029],
#  ['desperation', 1, 0.00029],
#  ['eglonitz', 1, 0.00029],
#  ['tall', 1, 0.00029],
#  ['passions', 1, 0.00029],
#  ['light', 1, 0.00029],
#  ['rose', 1, 0.00029],
#  ['scent', 1, 0.00029],
#  ['flaming', 1, 0.00029],
#  ['energy', 1, 0.00029],
#  ['curb', 1, 0.00029],
#  ['finally', 1, 0.00029],
#  ['ever', 1, 0.00029],
#  ['grating', 1, 0.00029],
#  ['habit', 1, 0.00029],
#  ['veil', 1, 0.00029],
#  ['mood', 1, 0.00029],
#  ['specimen', 1, 0.00029],
#  ['languid', 1, 0.00029],
#  ['updated', 1, 0.00029],
#  ['binding', 1, 0.00029],
#  ['imperial', 1, 0.00029],
#  ['open', 1, 0.00029],
#  ['sentence', 1, 0.00029],
#  ['pronounce', 1, 0.00029],
#  ['official', 1, 0.00029],
#  ['eye', 1, 0.00029],
#  ['successfully', 1, 0.00029],
#  ['thrown', 1, 0.00029],
#  ['rabbi', 1, 0.00029],
#  ['money', 1, 0.00029],
#  ['accustomed', 1, 0.00029],
#  ['acquaintance', 1, 0.00029],
#  ['sprang', 1, 0.00029],
#  ['scala', 1, 0.00029],
#  ['took', 1, 0.00029],
#  ['factor', 1, 0.00029],
#  ['occasionally', 1, 0.00029],
#  ['cuts', 1, 0.00029],
#  ['prague', 1, 0.00029],
#  ['clock', 1, 0.00029],
#  ['pink', 1, 0.00029],
#  ['dreadful', 1, 0.00029],
#  ['bottom', 1, 0.00029],
#  ['system', 1, 0.00029],
#  ['girl', 1, 0.00029],
#  ['crusted', 1, 0.00029],
#  ['strikes', 1, 0.00029],
#  ['lower', 1, 0.00029],
#  ['waylaid', 1, 0.00029],
#  ['putting', 1, 0.00029],
#  ['mysteries', 1, 0.00029],
#  ['stay', 1, 0.00029],
#  ['rubbed', 1, 0.00029],
#  ['miss', 1, 0.00029],
#  ['hopeless', 1, 0.00029],
#  ['absorb', 1, 0.00029],
#  ['wore', 1, 0.00029],
#  ['jose', 1, 0.00029],
#  ['viewing', 1, 0.00029],
#  ['european', 1, 0.00029],
#  ['tore', 1, 0.00029],
#  ['business', 1, 0.00029],
#  ['papers', 1, 0.00029],
#  ['machine', 1, 0.00029],
#  ['certificates', 1, 0.00029],
#  ['laughing', 1, 0.00029],
#  ['admit', 1, 0.00029],
#  ['precaution', 1, 0.00029],
#  ['want', 1, 0.00029],
#  ['window', 1, 0.00029],
#  ['member', 1, 0.00029],
#  ['indicated', 1, 0.00029],
#  ['explained', 1, 0.00029],
#  ['because', 1, 0.00029],
#  ['cheekbones', 1, 0.00029],
#  ['luggage', 1, 0.00029],
#  ['patient', 1, 0.00029],
#  ['diverted', 1, 0.00029],
#  ['neck', 1, 0.00029],
#  ['exaggerated', 1, 0.00029],
#  ['hurled', 1, 0.00029],
#  ['compromise', 1, 0.00029],
#  ['questionable', 1, 0.00029],
#  ['drifted', 1, 0.00029],
#  ['colleague', 1, 0.00029],
#  ['circumstances', 1, 0.00029],
#  ['absolutely', 1, 0.00029],
#  ['monogram', 1, 0.00029],
#  ['brimmed', 1, 0.00029],
#  ['mention', 1, 0.00029],
#  ['surprise', 1, 0.00029],
#  ['clumsy', 1, 0.00029],
#  ['doing', 1, 0.00029],
#  ['excuse', 1, 0.00029],
#  ['lit', 1, 0.00029],
#  ['cases', 1, 0.00029],
#  ['taken', 1, 0.00029],
#  ['certainly', 1, 0.00029],
#  ['loud', 1, 0.00029],
#  ['silhouette', 1, 0.00029],
#  ['trepoff', 1, 0.00029],
#  ['caught', 1, 0.00029],
#  ['tragedy', 1, 0.00029],
#  ['twist', 1, 0.00029],
#  ['followed', 1, 0.00029],
#  ['mistake', 1, 0.00029],
#  ['reasons', 1, 0.00029],
#  ['headed', 1, 0.00029],
#  ['length', 1, 0.00029],
#  ['band', 1, 0.00029],
#  ['passing', 1, 0.00029],
#  ['edit', 1, 0.00029],
#  ['follow', 1, 0.00029],
#  ['speaking', 1, 0.00029],
#  ['safely', 1, 0.00029],
#  ['mark', 1, 0.00029],
#  ['prince', 1, 0.00029],
#  ['finely', 1, 0.00029],
#  ['paced', 1, 0.00029],
#  ['vanilla', 1, 0.00029],
#  ['admirable', 1, 0.00029],
#  ['dreams', 1, 0.00029],
#  ['docketing', 1, 0.00029],
#  ['desirous', 1, 0.00029],
#  ['forgery', 1, 0.00029],
#  ['profession', 1, 0.00029],
#  ['distracting', 1, 0.00029],
#  ['laughed', 1, 0.00029],
#  ['propose', 1, 0.00029],
#  ['mistaken', 1, 0.00029],
#  ['abandoned', 1, 0.00029],
#  ['contraction', 1, 0.00029],
#  ['fronts', 1, 0.00029],
#  ['clothes', 1, 0.00029],
#  ['scarlet', 1, 0.00029],
#  ['clues', 1, 0.00029],
#  ['prefer', 1, 0.00029],
#  ['became', 1, 0.00029],
#  ['speak', 1, 0.00029],
#  ['side', 1, 0.00029],
#  ['monograph', 1, 0.00029],
#  ['rights', 1, 0.00029],
#  ['failed', 1, 0.00029],
#  ['civil', 1, 0.00029],
#  ['e', 1, 0.00029],
#  ['vizard', 1, 0.00029],
#  ['aloud', 1, 0.00029],
#  ['editing', 1, 0.00029],
#  ['flame', 1, 0.00029],
#  ['predominates', 1, 0.00029],
#  ['coronet', 1, 0.00029],
#  ['few', 1, 0.00029],
#  ['shrugged', 1, 0.00029],
#  ['stairs', 1, 0.00029],
#  ['capital', 1, 0.00029],
#  ['implicates', 1, 0.00029],
#  ['condescend', 1, 0.00029],
#  ['position', 1, 0.00029],
#  ['late', 1, 0.00029],
#  ['accent', 1, 0.00029],
#  ['able', 1, 0.00029],
#  ['2002', 1, 0.00029],
#  ['important', 1, 0.00029],
#  ['following', 1, 0.00029],
#  ['thousands', 1, 0.00029],
#  ['single', 1, 0.00029],
#  ['trust', 1, 0.00029],
#  ['placed', 1, 0.00029],
#  ['continental', 1, 0.00029],
#  ['lodgings', 1, 0.00029],
#  ['factories', 1, 0.00029],
#  ['straight', 1, 0.00029],
#  ['tap', 1, 0.00029],
#  ['promise', 1, 0.00029],
#  ['carlsbad', 1, 0.00029],
#  ['jersey', 1, 0.00029],
#  ['easily', 1, 0.00029],
#  ['indiscretion', 1, 0.00029],
#  ['top', 1, 0.00029],
#  ['sleeves', 1, 0.00029],
#  ['lenses', 1, 0.00029],
#  ['past', 1, 0.00029],
#  ['processes', 1, 0.00029],
#  ['course', 1, 0.00029],
#  ['love', 1, 0.00029],
#  ['grand', 1, 0.00029],
#  ['briefly', 1, 0.00029],
#  ['cigars', 1, 0.00029],
#  ['post', 1, 0.00029],
#  ['index', 1, 0.00029],
#  ['lined', 1, 0.00029],
#  ['unknown', 1, 0.00029],
#  ['brilliantly', 1, 0.00029],
#  ['absolute', 1, 0.00029],
#  ['hebrew', 1, 0.00029],
#  ['xi', 1, 0.00029],
#  ['summons', 1, 0.00029],
#  ['sheet', 1, 0.00029],
#  ['incidents', 1, 0.00029],
#  ['seventeen', 1, 0.00029],
#  ['begins', 1, 0.00029],
#  ['servant', 1, 0.00029],
#  ['sea', 1, 0.00029],
#  ['behind', 1, 0.00029],
#  ['included', 1, 0.00029],
#  ['find', 1, 0.00029],
#  ['cocaine', 1, 0.00029],
#  ['suggested', 1, 0.00029],
#  ['hundreds', 1, 0.00029],
#  ['caused', 1, 0.00029],
#  ['endeavouring', 1, 0.00029],
#  ['august', 1, 0.00029],
#  ['kramm', 1, 0.00029],
#  ['living', 1, 0.00029],
#  ['associated', 1, 0.00029],
#  ['alone', 1, 0.00029],
#  ['used', 1, 0.00029],
#  ['stage', 1, 0.00029],
#  ['mills', 1, 0.00029],
#  ['customary', 1, 0.00029],
#  ['bachelor', 1, 0.00029],
#  ['boy', 1, 0.00029],
#  ['sensitive', 1, 0.00029],
#  ['mary', 1, 0.00029],
#  ['white', 1, 0.00029],
#  ['lengthy', 1, 0.00029],
#  ['mission', 1, 0.00029],
#  ['risen', 1, 0.00029],
#  ['concerning', 1, 0.00029],
#  ['silk', 1, 0.00029],
#  ['drawing', 1, 0.00029],
#  ['woven', 1, 0.00029],
#  ['even', 1, 0.00029],
#  ['author', 1, 0.00029],
#  ['consisted', 1, 0.00029],
#  ['league', 1, 0.00029],
#  ['x', 1, 0.00029],
#  ['undated', 1, 0.00029],
#  ['limbs', 1, 0.00029],
#  ['society', 1, 0.00029],
#  ['slitting', 1, 0.00029],
#  ['glancing', 1, 0.00029],
#  ['pounds', 1, 0.00029],
#  ['communicate', 1, 0.00029],
#  ['showing', 1, 0.00029],
#  ['signature', 1, 0.00029],
#  ['hall', 1, 0.00029],
#  ['15', 1, 0.00029],
#  ['grow', 1, 0.00029],
#  ['authoritative', 1, 0.00029],
#  ['incognito', 1, 0.00029],
#  ['hanging', 1, 0.00029],
#  ['else', 1, 0.00029],
#  ['ix', 1, 0.00029],
#  ['1661', 1, 0.00029],
#  ['slowly', 1, 0.00029],
#  ['together', 1, 0.00029],
#  ['valley', 1, 0.00029],
#  ['abhorrent', 1, 0.00029],
#  ['height', 1, 0.00029],
#  ['identity', 1, 0.00029],
#  ['incisive', 1, 0.00029],
#  ['beyond', 1, 0.00029],
#  ['perfect', 1, 0.00029],
#  ['almost', 1, 0.00029],
#  ['plain', 1, 0.00029],
#  ['example', 1, 0.00029],
#  ['master', 1, 0.00029],
#  ['wooing', 1, 0.00029],
#  ['waved', 1, 0.00029],
#  ['eglow', 1, 0.00029],
#  ['speckled', 1, 0.00029],
#  ['smelling', 1, 0.00029],
#  ['sole', 1, 0.00029],
#  ['co', 1, 0.00029],
#  ['delicately', 1, 0.00029],
#  ['hear', 1, 0.00029],
#  ['sent', 1, 0.00029],
#  ['introspective', 1, 0.00029],
#  ['prepared', 1, 0.00029],
#  ['trusted', 1, 0.00029],
#  ['ruin', 1, 0.00029],
#  ['discretion', 1, 0.00029],
#  ['staff', 1, 0.00029],
#  ['lost', 1, 0.00029],
#  ['successive', 1, 0.00029],
#  ['prima', 1, 0.00029],
#  ['halfway', 1, 0.00029],
#  ['advise', 1, 0.00029],
#  ['series', 1, 0.00029],
#  ['dryly', 1, 0.00029],
#  ['papier', 1, 0.00029],
#  ['attitude', 1, 0.00029],
#  ['insensibly', 1, 0.00029],
#  ['hoofs', 1, 0.00029],
#  ['created', 1, 0.00029],
#  ['malignant', 1, 0.00029],
#  ['29', 1, 0.00029],
#  ['involved', 1, 0.00029],
#  ['sit', 1, 0.00029],
#  ['active', 1, 0.00029],
#  ['lead', 1, 0.00029],
#  ['less', 1, 0.00029],
#  ['frenchman', 1, 0.00029],
#  ['dr', 1, 0.00029],
#  ['books', 1, 0.00029],
#  ['changed', 1, 0.00029],
#  ['glass', 1, 0.00029],
#  ['second', 1, 0.00029],
#  ['beauties', 1, 0.00029],
#  ['wallenstein', 1, 0.00029],
#  ['texts', 1, 0.00029],
#  ['fancy', 1, 0.00029],
#  ['end', 1, 0.00029],
#  ['slavey', 1, 0.00029],
#  ['slashed', 1, 0.00029],
#  ['permission', 1, 0.00029],
#  ['old', 1, 0.00029],
#  ['scored', 1, 0.00029],
#  ['fierce', 1, 0.00029],
#  ['breasted', 1, 0.00029],
#  ['cold', 1, 0.00029],
#  ['felstein', 1, 0.00029],
#  ['opening', 1, 0.00029],
#  ['blind', 1, 0.00029],
#  ['boswell', 1, 0.00029],
#  ['extending', 1, 0.00029],
#  ['voice', 1, 0.00029],
#  ['lover', 1, 0.00029],
#  ['slow', 1, 0.00029],
#  ['means', 1, 0.00029],
#  ['called', 1, 0.00029],
#  ['guineas', 1, 0.00029],
#  ['writes', 1, 0.00029],
#  ['stiff', 1, 0.00029],
#  ['story', 1, 0.00029],
#  ['wearing', 1, 0.00029],
#  ['exactly', 1, 0.00029],
#  ['disturbing', 1, 0.00029],
#  ['changing', 1, 0.00029],
#  ['silver', 1, 0.00029],
#  ['however', 1, 0.00029],
#  ['spirit', 1, 0.00029],
#  ['crime', 1, 0.00029],
#  ['doings', 1, 0.00029],
#  ['carefully', 1, 0.00029],
#  ['theorise', 1, 0.00029],
#  ['pull', 1, 0.00029],
#  ['throw', 1, 0.00029],
#  ['fifty', 1, 0.00029],
#  ['found', 1, 0.00029],
#  ['orange', 1, 0.00029],
#  ['felt', 1, 0.00029],
#  ['don', 1, 0.00029],
#  ['left', 1, 0.00029],
#  ['raised', 1, 0.00029],
#  ['result', 1, 0.00029],
#  ['head', 1, 0.00029],
#  ['ease', 1, 0.00029],
#  ...]

# %%
prob = [lis[2] for lis in wordFreq if lis[0]=='want']
prob
# Out:
# [0.00029]

# %%
testWord = 'whant'

# %%
candidates1 = [word for word in set(word_list) if(abs(len(word)-len(testWord))<=1)]
#candidates2 = [word for word in set(word_list) if editDistance(word,testWord) == 1 ] 
candidates2 = [candidate for candidate in candidates1 if(editDistance(candidate, testWord)==1)]
candidates2
# Out:
# ['what', 'want']

# %%
#candidates2 = sorted(candidates1, key=lambda x: editDistance(testWord, x))

# %%
editDistance('oslo', 'snow')
# Out:
# 3
